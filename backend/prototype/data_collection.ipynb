# %%
from calendar import month

import requests, json
url = "https://gbfs.lyft.com/gbfs/1.1/bay/gbfs.json"
root = requests.get(url, timeout=15).json()
feeds = {f["name"]: f["url"] for f in root["data"]["en"]["feeds"]}
print(json.dumps(feeds, indent=2))
# Out:
# {
#   "gbfs": "https://gbfs.lyft.com/gbfs/1.1/bay/gbfs.json",
#   "ebikes_at_stations": "https://gbfs.lyft.com/gbfs/1.1/bay/en/ebikes_at_stations.json",
#   "system_information": "https://gbfs.lyft.com/gbfs/1.1/bay/en/system_information.json",
#   "station_information": "https://gbfs.lyft.com/gbfs/1.1/bay/en/station_information.json",
#   "station_status": "https://gbfs.lyft.com/gbfs/1.1/bay/en/station_status.json",
#   "free_bike_status": "https://gbfs.lyft.com/gbfs/1.1/bay/en/free_bike_status.json",
#   "system_hours": "https://gbfs.lyft.com/gbfs/1.1/bay/en/system_hours.json",
#   "system_calendar": "https://gbfs.lyft.com/gbfs/1.1/bay/en/system_calendar.json",
#   "system_regions": "https://gbfs.lyft.com/gbfs/1.1/bay/en/system_regions.json",
#   "system_pricing_plans": "https://gbfs.lyft.com/gbfs/1.1/bay/en/system_pricing_plans.json",
#   "system_alerts": "https://gbfs.lyft.com/gbfs/1.1/bay/en/system_alerts.json",
#   "gbfs_versions": "https://gbfs.lyft.com/gbfs/1.1/bay/en/gbfs_versions.json"
# }

# %% [markdown]
# # Static Data

# %%
import requests, json, os, datetime,glob
os.makedirs("data/raw", exist_ok=True)

url = "https://gbfs.lyft.com/gbfs/1.1/bay/en/station_information.json"
resp = requests.get(url, timeout=15)
resp.raise_for_status()
payload = resp.json()

payload = resp.json()

# %%
import requests, json, os, datetime,glob


# load latest station_information
stations = payload["data"]["stations"]

# load regions
import requests
regions = requests.get("https://gbfs.lyft.com/gbfs/1.1/bay/en/system_regions.json", timeout=15).json()["data"]["regions"]

print("Regions:", [ (r["region_id"], r["name"]) for r in regions ])

sj_region_ids = { r["region_id"] for r in regions if "san" in r["name"].lower() and "jose" in r["name"].lower() }
sj = [s for s in stations if s.get("region_id") in sj_region_ids]

print("San José stations:", len(sj))
print("Sample:", [{k:s.get(k) for k in ["station_id","name","lat","lon","capacity"]} for s in sj[:2]])
# Out:
# Regions: [('3', 'San Francisco'), ('5', 'San Jose'), ('12', 'Oakland'), ('13', 'Emeryville'), ('14', 'Berkeley'), ('23', '8D'), ('3', 'San Francisco'), ('5', 'San Jose'), ('12', 'Oakland'), ('13', 'Emeryville'), ('14', 'Berkeley'), ('23', '8D')]
# San José stations: 79
# Sample: [{'station_id': 'bae9be55-04d4-4641-9781-3d1c4b6950f1', 'name': 'Saint James Park', 'lat': 37.339301, 'lon': -121.889937, 'capacity': 15}, {'station_id': '68c89d1f-407a-4550-a2b7-ecf0ad7ee422', 'name': 'San Carlos St at Meridian Ave', 'lat': 37.3233446905968, 'lon': -121.91349685192107, 'capacity': 19}]

# %%
sj
# Out:
# [{'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Saint James Park',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-L10',
#   'capacity': 15,
#   'station_id': 'bae9be55-04d4-4641-9781-3d1c4b6950f1',
#   'lon': -121.889937,
#   'has_kiosk': True,
#   'external_id': 'bae9be55-04d4-4641-9781-3d1c4b6950f1',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.339301,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'San Carlos St at Meridian Ave',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-M4',
#   'capacity': 19,
#   'station_id': '68c89d1f-407a-4550-a2b7-ecf0ad7ee422',
#   'lon': -121.91349685192107,
#   'has_kiosk': True,
#   'external_id': '68c89d1f-407a-4550-a2b7-ecf0ad7ee422',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.3233446905968,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'San Jose Diridon Station',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-M7-1',
#   'capacity': 35,
#   'station_id': 'dc2f7685-c3e3-4536-b78b-740479cbb207',
#   'lon': -121.901782,
#   'has_kiosk': True,
#   'external_id': 'dc2f7685-c3e3-4536-b78b-740479cbb207',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.329732,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'San Fernando St at 7th St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-M11-2',
#   'capacity': 23,
#   'station_id': 'ed707a89-a68d-4921-a4cb-16c268e45a5b',
#   'lon': -121.88321471214294,
#   'has_kiosk': True,
#   'external_id': 'ed707a89-a68d-4921-a4cb-16c268e45a5b',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.3371223728942,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Bestor Art Park',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-Q11',
#   'capacity': 15,
#   'station_id': '46b4ef45-b06b-40eb-9fdf-9bc8ff104a4f',
#   'lon': -121.8741186,
#   'has_kiosk': True,
#   'external_id': '46b4ef45-b06b-40eb-9fdf-9bc8ff104a4f',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.3236779,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Mission St at 1st St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-H10',
#   'capacity': 27,
#   'station_id': '0d730ac1-7ce6-45cf-aca6-b412ea46709d',
#   'lon': -121.9020161,
#   'has_kiosk': True,
#   'external_id': '0d730ac1-7ce6-45cf-aca6-b412ea46709d',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.3509643,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Stockton Ave at Lenzen Ave',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-J6',
#   'capacity': 23,
#   'station_id': 'd75591d7-080d-46cb-8ada-0fbe6af676fc',
#   'lon': -121.90914899110793,
#   'has_kiosk': True,
#   'external_id': 'd75591d7-080d-46cb-8ada-0fbe6af676fc',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.33677476275722,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Julian St at 6th St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-K11',
#   'capacity': 15,
#   'station_id': '0d48fc9e-6798-46f0-bbb6-67a168800e0b',
#   'lon': -121.8888891,
#   'has_kiosk': True,
#   'external_id': '0d48fc9e-6798-46f0-bbb6-67a168800e0b',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.3429973,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': '23rd St at Taylor St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-I14',
#   'capacity': 19,
#   'station_id': '7d59176c-49dd-4b07-a5ab-bcc109974db3',
#   'lon': -121.87877833843231,
#   'has_kiosk': True,
#   'external_id': '7d59176c-49dd-4b07-a5ab-bcc109974db3',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.3600013909666,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Kerley Dr at Rosemary St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-F10',
#   'capacity': 27,
#   'station_id': 'ab8cc22e-0f34-4476-bf81-293cbbb2e69c',
#   'lon': -121.90683424472809,
#   'has_kiosk': True,
#   'external_id': 'ab8cc22e-0f34-4476-bf81-293cbbb2e69c',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.360854155253826,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': '23rd St at Santa Clara St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-M14',
#   'capacity': 19,
#   'station_id': 'c53990d7-f965-40f4-b305-3435e1c95a71',
#   'lon': -121.86856960181206,
#   'has_kiosk': True,
#   'external_id': 'c53990d7-f965-40f4-b305-3435e1c95a71',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.346480293729044,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Newbury Park Dr at King Rd',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-H17',
#   'capacity': 23,
#   'station_id': '6994e1e6-bb3c-4309-8207-52e6004a7302',
#   'lon': -121.86796635389327,
#   'has_kiosk': True,
#   'external_id': '6994e1e6-bb3c-4309-8207-52e6004a7302',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.3655356585599,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': '17th St at Santa Clara St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-L13',
#   'capacity': 19,
#   'station_id': '30429aed-9a47-4fd9-87fa-0db835aa8265',
#   'lon': -121.87438488006593,
#   'has_kiosk': True,
#   'external_id': '30429aed-9a47-4fd9-87fa-0db835aa8265',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.34398467798214,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'The Alameda at Bush St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-L7-2',
#   'capacity': 23,
#   'station_id': 'd28bb0a7-8dc5-49be-86c7-9a3395eed019',
#   'lon': -121.9048882,
#   'has_kiosk': True,
#   'external_id': 'd28bb0a7-8dc5-49be-86c7-9a3395eed019',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.3319323,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Asbury St at The Alameda',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-I5',
#   'capacity': 23,
#   'station_id': 'a96032c0-9ff2-4fbe-8f03-6b3f9816947d',
#   'lon': -121.91947817802429,
#   'has_kiosk': True,
#   'external_id': 'a96032c0-9ff2-4fbe-8f03-6b3f9816947d',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.33802231313689,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'San Fernando St at 4th St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-M10-2',
#   'capacity': 23,
#   'station_id': 'c52ca98a-70c6-42da-9867-4f35060b5d2e',
#   'lon': -121.88566,
#   'has_kiosk': True,
#   'external_id': 'c52ca98a-70c6-42da-9867-4f35060b5d2e',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.335885,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Willow St at Vine St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-Q9',
#   'capacity': 14,
#   'station_id': 'adda58ee-59a9-4586-8210-da874168a93b',
#   'lon': -121.8831724,
#   'has_kiosk': True,
#   'external_id': 'adda58ee-59a9-4586-8210-da874168a93b',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.3184498,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Saint James St at 9th St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-L11',
#   'capacity': 19,
#   'station_id': '218e755d-c0d3-4b33-8afc-b4b0e8ab3a41',
#   'lon': -121.88438951969147,
#   'has_kiosk': True,
#   'external_id': '218e755d-c0d3-4b33-8afc-b4b0e8ab3a41',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.343208488473465,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Autumn Parkway at Coleman Ave',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-J8',
#   'capacity': 15,
#   'station_id': '3ebc4f3f-2941-47cd-a173-83f01a91bf57',
#   'lon': -121.9031829,
#   'has_kiosk': True,
#   'external_id': '3ebc4f3f-2941-47cd-a173-83f01a91bf57',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.3413348,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'SAP Center',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-L7-1',
#   'capacity': 23,
#   'station_id': 'daac8a55-dd65-4a1e-b0b9-65ec5002c812',
#   'lon': -121.900084,
#   'has_kiosk': True,
#   'external_id': 'daac8a55-dd65-4a1e-b0b9-65ec5002c812',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.332692,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Bird Ave at Willow St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-Q5',
#   'capacity': 19,
#   'station_id': '4e704be5-b76d-44a5-8d05-a9ba3e5ae20e',
#   'lon': -121.89632534980774,
#   'has_kiosk': True,
#   'external_id': '4e704be5-b76d-44a5-8d05-a9ba3e5ae20e',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.31128394611736,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': '7th St at Empire St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-J11',
#   'capacity': 31,
#   'station_id': 'bd05ae96-7adc-422d-84ea-697cd3b73afc',
#   'lon': -121.89055323600769,
#   'has_kiosk': True,
#   'external_id': 'bd05ae96-7adc-422d-84ea-697cd3b73afc',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.3477119817597,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Fountain Alley at S 2nd St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-M10-4',
#   'capacity': 11,
#   'station_id': 'd12ba265-5bfe-4a00-a19a-a7299822bd65',
#   'lon': -121.88927650451659,
#   'has_kiosk': True,
#   'external_id': 'd12ba265-5bfe-4a00-a19a-a7299822bd65',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.33618830029063,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Delmas Ave and San Fernando St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-M8-2',
#   'capacity': 19,
#   'station_id': '6bcc6da3-b25b-4fea-9c30-3eb88e282574',
#   'lon': -121.8977018,
#   'has_kiosk': True,
#   'external_id': '6bcc6da3-b25b-4fea-9c30-3eb88e282574',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.3302641,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'San Pedro Square',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-L9',
#   'capacity': 15,
#   'station_id': 'fa83f661-540e-4720-9323-824c6529b796',
#   'lon': -121.8940901,
#   'has_kiosk': True,
#   'external_id': 'fa83f661-540e-4720-9323-824c6529b796',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.336802,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Mercado Way at Sierra Rd',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-G15',
#   'capacity': 19,
#   'station_id': '3c12fd1d-c7fc-4570-8fa3-1449c096b818',
#   'lon': -121.88133180141449,
#   'has_kiosk': True,
#   'external_id': '3c12fd1d-c7fc-4570-8fa3-1449c096b818',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.37111641335901,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Metro Dr at Technology Dr',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-C9',
#   'capacity': 23,
#   'station_id': 'e81efb0f-faee-43dd-b8e0-1e1f0cad61f1',
#   'lon': -121.9187942147255,
#   'has_kiosk': True,
#   'external_id': 'e81efb0f-faee-43dd-b8e0-1e1f0cad61f1',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.36767805240811,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': '5th St at Taylor St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-I10',
#   'capacity': 23,
#   'station_id': '8941eac9-fb07-4d76-b623-fae2af79139e',
#   'lon': -121.89584255218504,
#   'has_kiosk': True,
#   'external_id': '8941eac9-fb07-4d76-b623-fae2af79139e',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.35090179274617,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Pierce Ave at Market St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-O10',
#   'capacity': 27,
#   'station_id': 'd6c452d5-88d5-48e2-8028-d46134c2beb8',
#   'lon': -121.884559,
#   'has_kiosk': True,
#   'external_id': 'd6c452d5-88d5-48e2-8028-d46134c2beb8',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.327581,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Park Ave at Laurel Grove Ln',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-M6-2',
#   'capacity': 19,
#   'station_id': '14f62ff9-1893-4379-8fe4-db578da909ee',
#   'lon': -121.9049111008644,
#   'has_kiosk': True,
#   'external_id': '14f62ff9-1893-4379-8fe4-db578da909ee',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.326282324105776,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Santa Clara St at Almaden Blvd',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-M9-2',
#   'capacity': 11,
#   'station_id': '67b039eb-ea61-46c0-8da5-1f56de4ad9ca',
#   'lon': -121.894902,
#   'has_kiosk': True,
#   'external_id': '67b039eb-ea61-46c0-8da5-1f56de4ad9ca',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.333988,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': '1st St at Younger Ave',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-G10',
#   'capacity': 19,
#   'station_id': '3794a34d-764a-4af1-80db-1b0e0ce13fed',
#   'lon': -121.90443634986876,
#   'has_kiosk': True,
#   'external_id': '3794a34d-764a-4af1-80db-1b0e0ce13fed',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.355029582252904,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Santa Clara St at 7th St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-M11-1',
#   'capacity': 15,
#   'station_id': '7ae6ad74-9212-4a2b-bb52-aba03cb533e2',
#   'lon': -121.8841054,
#   'has_kiosk': True,
#   'external_id': '7ae6ad74-9212-4a2b-bb52-aba03cb533e2',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.3391456,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Oak St at 1st St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-P9',
#   'capacity': 23,
#   'station_id': '0fd9a51c-67ac-4048-b531-bff644b82f47',
#   'lon': -121.88109040260315,
#   'has_kiosk': True,
#   'external_id': '0fd9a51c-67ac-4048-b531-bff644b82f47',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.322124625448566,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Locust St at Grant St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-P8',
#   'capacity': 19,
#   'station_id': '676591be-48bc-4653-995a-c4536e793135',
#   'lon': -121.8879312,
#   'has_kiosk': True,
#   'external_id': '676591be-48bc-4653-995a-c4536e793135',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.3229796,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'San Salvador St at 9th St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-N11',
#   'capacity': 19,
#   'station_id': '53d1c097-50e3-494d-bddc-bdab49c7c39b',
#   'lon': -121.877349,
#   'has_kiosk': True,
#   'external_id': '53d1c097-50e3-494d-bddc-bdab49c7c39b',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.333955,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Paseo De San Antonio at 2nd St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-M10-3',
#   'capacity': 19,
#   'station_id': '891b961d-b674-49be-9579-71f5feb4598d',
#   'lon': -121.886943,
#   'has_kiosk': True,
#   'external_id': '891b961d-b674-49be-9579-71f5feb4598d',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.333798,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Almaden Blvd at Balbach St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-O9',
#   'capacity': 19,
#   'station_id': '8fccc336-6544-4c73-a096-282131267f78',
#   'lon': -121.88920147407019,
#   'has_kiosk': True,
#   'external_id': '8fccc336-6544-4c73-a096-282131267f78',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.326845739588315,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Auzerais Ave at Lincoln Ave',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-N5-2',
#   'capacity': 27,
#   'station_id': '14750571-71a2-4c2f-8a6a-8f344866eebe',
#   'lon': -121.90829604864119,
#   'has_kiosk': True,
#   'external_id': '14750571-71a2-4c2f-8a6a-8f344866eebe',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.32096853145443,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Skyport Dr at Technology Dr',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-D9',
#   'capacity': 19,
#   'station_id': '938f4dc0-e393-47e8-9449-3a82b2445662',
#   'lon': -121.9168147444725,
#   'has_kiosk': True,
#   'external_id': '938f4dc0-e393-47e8-9449-3a82b2445662',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.36522655191025,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'William St at 10th St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-O12',
#   'capacity': 23,
#   'station_id': '753e3e72-9498-4eef-a006-be1848cb36b3',
#   'lon': -121.8759263,
#   'has_kiosk': True,
#   'external_id': '753e3e72-9498-4eef-a006-be1848cb36b3',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.3327938,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Raymond Bernal Jr Memorial Park',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-H11',
#   'capacity': 23,
#   'station_id': 'c0f36b61-82e5-4f63-9a28-1fa11f0149c9',
#   'lon': -121.89593575894831,
#   'has_kiosk': True,
#   'external_id': 'c0f36b61-82e5-4f63-9a28-1fa11f0149c9',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.356834352780886,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': '4th St at San Carlos St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-N10-1',
#   'capacity': 19,
#   'station_id': '453a6d0d-31ce-4204-b2e1-2f9532e4b356',
#   'lon': -121.88385039567946,
#   'has_kiosk': True,
#   'external_id': '453a6d0d-31ce-4204-b2e1-2f9532e4b356',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.33279952386071,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': '19th St at William St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-N14-2',
#   'capacity': 15,
#   'station_id': 'ea511b7f-eae4-4ee8-9bba-ee7445e5133a',
#   'lon': -121.86652064323424,
#   'has_kiosk': True,
#   'external_id': 'ea511b7f-eae4-4ee8-9bba-ee7445e5133a',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.338468014146,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Almaden Blvd at San Fernando St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-M8-1',
#   'capacity': 23,
#   'station_id': '32974dc6-2aea-45d3-ae66-06f02f45ecaa',
#   'lon': -121.8932,
#   'has_kiosk': True,
#   'external_id': '32974dc6-2aea-45d3-ae66-06f02f45ecaa',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.331415,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'San Carlos St at 11th St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-N12-1',
#   'capacity': 19,
#   'station_id': 'dc464713-3263-40bd-a059-af2efd7a4b9a',
#   'lon': -121.8766132,
#   'has_kiosk': True,
#   'external_id': 'dc464713-3263-40bd-a059-af2efd7a4b9a',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.3364659,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'San Jose City Hall',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-M10-1',
#   'capacity': 23,
#   'station_id': '5c17e1c8-5d21-4309-afcb-e69da27acf31',
#   'lon': -121.886995,
#   'has_kiosk': True,
#   'external_id': '5c17e1c8-5d21-4309-afcb-e69da27acf31',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.337391,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Cahill Park',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-M6',
#   'capacity': 23,
#   'station_id': '28988488-fb74-4bbc-9e69-613698b2dd8c',
#   'lon': -121.90457582473755,
#   'has_kiosk': True,
#   'external_id': '28988488-fb74-4bbc-9e69-613698b2dd8c',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.32911866814779,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Empire St at 1st St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-J9',
#   'capacity': 19,
#   'station_id': '7d8f4de7-d726-4af2-95b5-33032136239a',
#   'lon': -121.8969655,
#   'has_kiosk': True,
#   'external_id': '7d8f4de7-d726-4af2-95b5-33032136239a',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.3448821,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Sonora Ave at 1st St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-E9',
#   'capacity': 15,
#   'station_id': 'cfda2dee-2f6c-400d-a1a7-ba1b2bdc6aee',
#   'lon': -121.9117319583893,
#   'has_kiosk': True,
#   'external_id': 'cfda2dee-2f6c-400d-a1a7-ba1b2bdc6aee',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.364060462258806,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Julian St at The Alameda',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-K5',
#   'capacity': 23,
#   'station_id': '2c7560e6-62c6-4403-8b97-8016471948b5',
#   'lon': -121.9125165,
#   'has_kiosk': True,
#   'external_id': '2c7560e6-62c6-4403-8b97-8016471948b5',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.3322326,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Gish Rd at 1st St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-E10',
#   'capacity': 23,
#   'station_id': 'b8cadddb-5ca8-43ec-98f3-2276e036950b',
#   'lon': -121.90931528806688,
#   'has_kiosk': True,
#   'external_id': 'b8cadddb-5ca8-43ec-98f3-2276e036950b',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.36186680025918,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': '5th St at Virginia St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-P10',
#   'capacity': 27,
#   'station_id': 'bb54f5c8-5578-4167-9599-8e55154de4fd',
#   'lon': -121.87712,
#   'has_kiosk': True,
#   'external_id': 'bb54f5c8-5578-4167-9599-8e55154de4fd',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.3259984,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Park Ave at Race St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-M5',
#   'capacity': 23,
#   'station_id': '45d77294-6643-4ba4-bd8b-2e8c27430dfe',
#   'lon': -121.91232740879057,
#   'has_kiosk': True,
#   'external_id': '45d77294-6643-4ba4-bd8b-2e8c27430dfe',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.32601084794081,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Taylor St at 9th St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-I11',
#   'capacity': 23,
#   'station_id': 'd87d0852-6abb-428b-86dd-d470c64c8ff7',
#   'lon': -121.89193725585936,
#   'has_kiosk': True,
#   'external_id': 'd87d0852-6abb-428b-86dd-d470c64c8ff7',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.35306166133104,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Delmas Ave at Virginia St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-P7',
#   'capacity': 19,
#   'station_id': 'ea2a009b-6a83-4b81-ba35-c175c492f4f4',
#   'lon': -121.89322043713115,
#   'has_kiosk': True,
#   'external_id': 'ea2a009b-6a83-4b81-ba35-c175c492f4f4',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.31998798619738,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': '9th St at San Fernando St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-M11-3',
#   'capacity': 19,
#   'station_id': '7dfd8e07-81a8-4734-bc70-5e47aadbfa5a',
#   'lon': -121.8807965,
#   'has_kiosk': True,
#   'external_id': '7dfd8e07-81a8-4734-bc70-5e47aadbfa5a',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.3383952,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Jackson St at 5th St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-J10',
#   'capacity': 27,
#   'station_id': 'd6422284-e433-48c5-bf00-751c299189c8',
#   'lon': -121.89479783177376,
#   'has_kiosk': True,
#   'external_id': 'd6422284-e433-48c5-bf00-751c299189c8',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.3487586867448,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'San Carlos St at Market St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-N9',
#   'capacity': 15,
#   'station_id': 'caadcda3-bbdb-4cc5-825a-7e3d79ea921e',
#   'lon': -121.888979,
#   'has_kiosk': True,
#   'external_id': 'caadcda3-bbdb-4cc5-825a-7e3d79ea921e',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.330698,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Devine St at San Pedro St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-L9-2',
#   'capacity': 23,
#   'station_id': 'd68c980f-e659-4407-8e69-fea3ea84476a',
#   'lon': -121.89564406871794,
#   'has_kiosk': True,
#   'external_id': 'd68c980f-e659-4407-8e69-fea3ea84476a',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.338670604639425,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'N Morrison Ave at W Julian St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-K6',
#   'capacity': 19,
#   'station_id': '27045384-791c-4519-8087-fce2f7c48a69',
#   'lon': -121.90861791372298,
#   'has_kiosk': True,
#   'external_id': '27045384-791c-4519-8087-fce2f7c48a69',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.333677122859896,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Willow St at Blewett Ave',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-Q4',
#   'capacity': 23,
#   'station_id': 'cf792877-0b6a-4594-b388-8eb06599b549',
#   'lon': -121.9000107049942,
#   'has_kiosk': True,
#   'external_id': 'cf792877-0b6a-4594-b388-8eb06599b549',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.309014074275915,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Berryessa BART',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-H16',
#   'capacity': 25,
#   'station_id': '93d95ded-d49e-43bc-b7fe-6ce556569088',
#   'lon': -121.87161205351002,
#   'has_kiosk': True,
#   'external_id': '93d95ded-d49e-43bc-b7fe-6ce556569088',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.36508806048156,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Palm St at Willow St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-Q8',
#   'capacity': 19,
#   'station_id': '0cf3890c-4fde-49f7-9daa-7f2842695119',
#   'lon': -121.884995,
#   'has_kiosk': True,
#   'external_id': '0cf3890c-4fde-49f7-9daa-7f2842695119',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.3172979,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Ryland Park',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-K9',
#   'capacity': 23,
#   'station_id': '13d36dad-f238-426c-9525-ec73552fa0b0',
#   'lon': -121.895617,
#   'has_kiosk': True,
#   'external_id': '13d36dad-f238-426c-9525-ec73552fa0b0',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.342725,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': '22nd St at William St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-N14',
#   'capacity': 15,
#   'station_id': '59a78eb1-a501-4145-b21f-bc2397898905',
#   'lon': -121.8636494,
#   'has_kiosk': True,
#   'external_id': '59a78eb1-a501-4145-b21f-bc2397898905',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.3398531,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Backesto Park',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-J12-2',
#   'capacity': 15,
#   'station_id': '534d8e3d-3814-48c9-b25e-1d2b8205fcd9',
#   'lon': -121.88604980707169,
#   'has_kiosk': True,
#   'external_id': '534d8e3d-3814-48c9-b25e-1d2b8205fcd9',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.35288682729121,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': '10th St at Mission St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-H12',
#   'capacity': 23,
#   'station_id': '6200707a-ffec-4dde-b142-4df69780264f',
#   'lon': -121.89225107431412,
#   'has_kiosk': True,
#   'external_id': '6200707a-ffec-4dde-b142-4df69780264f',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.355692651246365,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Parkmoor Ave at Race St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-O4',
#   'capacity': 27,
#   'station_id': '2c00d99d-7518-4ecd-ab53-63e7a34034f6',
#   'lon': -121.91000461578369,
#   'has_kiosk': True,
#   'external_id': '2c00d99d-7518-4ecd-ab53-63e7a34034f6',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.316736478493425,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': '10th St at Empire St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-J12-1',
#   'capacity': 23,
#   'station_id': '7c086aa7-c33f-47e5-ace9-74c40807c409',
#   'lon': -121.8876188993454,
#   'has_kiosk': True,
#   'external_id': '7c086aa7-c33f-47e5-ace9-74c40807c409',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.349426308788004,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Sunol St at San Carlos St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-N5',
#   'capacity': 27,
#   'station_id': 'e5b1f228-5347-47fc-a079-c1df0e8668f1',
#   'lon': -121.90597593784332,
#   'has_kiosk': True,
#   'external_id': 'e5b1f228-5347-47fc-a079-c1df0e8668f1',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.32345133870681,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'N 14th St at E Santa Clara St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-L12',
#   'capacity': 23,
#   'station_id': 'b6d76c7a-2082-430b-8403-da5db00becaf',
#   'lon': -121.87729239463806,
#   'has_kiosk': True,
#   'external_id': 'b6d76c7a-2082-430b-8403-da5db00becaf',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.3426625921454,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Auzerais Ave at Los Gatos Creek Trail',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-N6',
#   'capacity': 23,
#   'station_id': '46f36a3a-f550-4fe0-bfe8-b94fddaf95d8',
#   'lon': -121.9030898809433,
#   'has_kiosk': True,
#   'external_id': '46f36a3a-f550-4fe0-bfe8-b94fddaf95d8',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.321181834267314,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Bird Ave at Coe Ave',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-P6',
#   'capacity': 15,
#   'station_id': 'b09fd293-4364-4ce6-9341-0ced58486c5a',
#   'lon': -121.89783275127412,
#   'has_kiosk': True,
#   'external_id': 'b09fd293-4364-4ce6-9341-0ced58486c5a',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.31515792998312,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'George St at 1st St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-I9',
#   'capacity': 19,
#   'station_id': '6c176d42-fea5-4df1-80eb-66a99cc73a21',
#   'lon': -121.89966201782227,
#   'has_kiosk': True,
#   'external_id': '6c176d42-fea5-4df1-80eb-66a99cc73a21',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.34759257443888,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': '2nd St at Julian St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-K10',
#   'capacity': 23,
#   'station_id': 'ccf416f8-ccc0-4f82-a659-e5d7851d2bcb',
#   'lon': -121.89284384250641,
#   'has_kiosk': True,
#   'external_id': 'ccf416f8-ccc0-4f82-a659-e5d7851d2bcb',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.34113203547954,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'Columbia Ave at Bird Ave',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-N7',
#   'capacity': 23,
#   'station_id': 'eb283c26-5d6b-4da4-a2ac-f0bfe3329856',
#   'lon': -121.89971968531609,
#   'has_kiosk': True,
#   'external_id': 'eb283c26-5d6b-4da4-a2ac-f0bfe3329856',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.324125951150876,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': 'South San Jose State',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-R11',
#   'capacity': 31,
#   'station_id': '94c877d2-f064-4373-b372-3f8997a07f30',
#   'lon': -121.87009871006012,
#   'has_kiosk': True,
#   'external_id': '94c877d2-f064-4373-b372-3f8997a07f30',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.32031582108647,
#   'station_type': 'classic'},
#  {'eightd_station_services': [],
#   'electric_bike_surcharge_waiver': False,
#   'eightd_has_key_dispenser': False,
#   'name': '5th St at San Salvador St',
#   'region_id': '5',
#   'rental_methods': ['KEY', 'CREDITCARD'],
#   'short_name': 'SJ-N10-3',
#   'capacity': 19,
#   'station_id': 'bd217291-f4ad-4e1d-8c13-e27d39a35fef',
#   'lon': -121.8817663192749,
#   'has_kiosk': True,
#   'external_id': 'bd217291-f4ad-4e1d-8c13-e27d39a35fef',
#   'rental_uris': {'ios': 'https://sfo.lft.to/lastmile_qr_scan',
#    'android': 'https://sfo.lft.to/lastmile_qr_scan'},
#   'lat': 37.33203868095132,
#   'station_type': 'classic'}]

# %%
import pandas as pd

df = pd.DataFrame(sj)
df = df.drop(['has_kiosk','rental_uris','eightd_has_key_dispenser','electric_bike_surcharge_waiver','external_id','external_id','eightd_station_services'],axis =1)
df.columns
# Out:
# Index(['station_id', 'rental_methods', 'name', 'capacity', 'lon', 'short_name',
#        'region_id', 'station_type', 'lat'],
#       dtype='object')

# %%
df.head()
# Out:
#                              station_id     rental_methods  \
# 0  c53990d7-f965-40f4-b305-3435e1c95a71  [KEY, CREDITCARD]
# 1  30429aed-9a47-4fd9-87fa-0db835aa8265  [KEY, CREDITCARD]
# 2  0d730ac1-7ce6-45cf-aca6-b412ea46709d  [KEY, CREDITCARD]
# 3  bae9be55-04d4-4641-9781-3d1c4b6950f1  [KEY, CREDITCARD]
# 4  ed707a89-a68d-4921-a4cb-16c268e45a5b  [KEY, CREDITCARD]
#
#                         name  capacity         lon short_name region_id  \
# 0  23rd St at Santa Clara St        19 -121.868570     SJ-M14         5
# 1  17th St at Santa Clara St        19 -121.874385     SJ-L13         5
# 2       Mission St at 1st St        27 -121.902016     SJ-H10         5
# 3           Saint James Park        15 -121.889937     SJ-L10         5
# 4  San Fernando St at 7th St        23 -121.883215   SJ-M11-2         5
#
#   station_type        lat
# 0      classic  37.346480
# 1      classic  37.343985
# 2      classic  37.350964
# 3      classic  37.339301
# 4      classic  37.337122

# %%
# Temp solution
station_id_list ={}

for i in df["station_id"]:
    station_id_list[i] = "SJ"

len(station_id_list)
# Out:
# 79

# %% [markdown]
# ## Live Data

# %%
import requests,os
url ='https://gbfs.lyft.com/gbfs/1.1/bay/en/station_status.json'
resp = requests.get(url, timeout=15)
resp.raise_for_status()
payload = resp.json()

payload = resp.json()

# %%
stations = payload["data"]["stations"]

len(stations)

stations
# Out:
# [{'station_id': '46b4ef45-b06b-40eb-9fdf-9bc8ff104a4f',
#   'last_reported': 1754985922,
#   'num_ebikes_available': 2,
#   'legacy_id': '299',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 7,
#   'num_bikes_available': 8,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '0d48fc9e-6798-46f0-bbb6-67a168800e0b',
#   'last_reported': 1754985938,
#   'num_ebikes_available': 4,
#   'legacy_id': '275',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 4,
#   'num_bikes_available': 11,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '7d59176c-49dd-4b07-a5ab-bcc109974db3',
#   'last_reported': 1754985966,
#   'num_ebikes_available': 6,
#   'legacy_id': '421',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 4,
#   'num_bikes_available': 15,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'ab8cc22e-0f34-4476-bf81-293cbbb2e69c',
#   'last_reported': 1754985971,
#   'num_ebikes_available': 1,
#   'legacy_id': '395',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 20,
#   'num_bikes_available': 7,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'bae9be55-04d4-4641-9781-3d1c4b6950f1',
#   'last_reported': 1754985982,
#   'num_ebikes_available': 11,
#   'legacy_id': '306',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 4,
#   'num_bikes_available': 11,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '68c89d1f-407a-4550-a2b7-ecf0ad7ee422',
#   'last_reported': 1754985983,
#   'num_ebikes_available': 9,
#   'legacy_id': '426',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 4,
#   'num_bikes_available': 15,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '0d730ac1-7ce6-45cf-aca6-b412ea46709d',
#   'last_reported': 1754985993,
#   'num_ebikes_available': 7,
#   'legacy_id': '288',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 12,
#   'num_bikes_available': 14,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'd75591d7-080d-46cb-8ada-0fbe6af676fc',
#   'last_reported': 1754985987,
#   'num_ebikes_available': 15,
#   'legacy_id': '422',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 2,
#   'num_bikes_available': 21,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '30429aed-9a47-4fd9-87fa-0db835aa8265',
#   'last_reported': 1754985999,
#   'num_ebikes_available': 2,
#   'legacy_id': '418',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 10,
#   'num_bikes_available': 8,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'dc2f7685-c3e3-4536-b78b-740479cbb207',
#   'last_reported': 1754986004,
#   'num_ebikes_available': 18,
#   'legacy_id': '312',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 16,
#   'num_bikes_available': 18,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'c53990d7-f965-40f4-b305-3435e1c95a71',
#   'last_reported': 1754986002,
#   'num_ebikes_available': 17,
#   'legacy_id': '404',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 0,
#   'num_bikes_available': 18,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'ed707a89-a68d-4921-a4cb-16c268e45a5b',
#   'last_reported': 1754986002,
#   'num_ebikes_available': 3,
#   'legacy_id': '280',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 20,
#   'num_bikes_available': 3,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '6994e1e6-bb3c-4309-8207-52e6004a7302',
#   'last_reported': 1754986002,
#   'num_ebikes_available': 2,
#   'legacy_id': '442',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 13,
#   'num_bikes_available': 10,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '67b039eb-ea61-46c0-8da5-1f56de4ad9ca',
#   'last_reported': 1754985931,
#   'num_ebikes_available': 2,
#   'legacy_id': '314',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 1,
#   'num_bikes_available': 10,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'a96032c0-9ff2-4fbe-8f03-6b3f9816947d',
#   'last_reported': 1754985936,
#   'num_ebikes_available': 12,
#   'legacy_id': '393',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 0,
#   'num_bikes_available': 23,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '4e704be5-b76d-44a5-8d05-a9ba3e5ae20e',
#   'last_reported': 1754985938,
#   'num_ebikes_available': 16,
#   'legacy_id': '425',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 0,
#   'num_bikes_available': 19,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'd28bb0a7-8dc5-49be-86c7-9a3395eed019',
#   'last_reported': 1754985944,
#   'num_ebikes_available': 8,
#   'legacy_id': '278',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 9,
#   'num_bikes_available': 14,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'bd05ae96-7adc-422d-84ea-697cd3b73afc',
#   'last_reported': 1754985947,
#   'num_ebikes_available': 8,
#   'legacy_id': '378',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 0,
#   'num_bikes_available': 31,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'e81efb0f-faee-43dd-b8e0-1e1f0cad61f1',
#   'last_reported': 1754985945,
#   'num_ebikes_available': 9,
#   'legacy_id': '396',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 10,
#   'num_bikes_available': 13,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'c52ca98a-70c6-42da-9867-4f35060b5d2e',
#   'last_reported': 1754985950,
#   'num_ebikes_available': 10,
#   'legacy_id': '310',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 5,
#   'num_bikes_available': 18,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'fa83f661-540e-4720-9323-824c6529b796',
#   'last_reported': 1754985951,
#   'num_ebikes_available': 8,
#   'legacy_id': '308',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 5,
#   'num_bikes_available': 10,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'd12ba265-5bfe-4a00-a19a-a7299822bd65',
#   'last_reported': 1754985954,
#   'num_ebikes_available': 0,
#   'legacy_id': '341',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 0,
#   'num_bikes_available': 10,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '3ebc4f3f-2941-47cd-a173-83f01a91bf57',
#   'last_reported': 1754985967,
#   'num_ebikes_available': 2,
#   'legacy_id': '291',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 1,
#   'num_bikes_available': 14,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '53d1c097-50e3-494d-bddc-bdab49c7c39b',
#   'last_reported': 1754985899,
#   'num_ebikes_available': 2,
#   'legacy_id': '317',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 12,
#   'num_bikes_available': 5,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '218e755d-c0d3-4b33-8afc-b4b0e8ab3a41',
#   'last_reported': 1754985904,
#   'num_ebikes_available': 9,
#   'legacy_id': '495',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 6,
#   'num_bikes_available': 13,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'd6c452d5-88d5-48e2-8028-d46134c2beb8',
#   'last_reported': 1754985988,
#   'num_ebikes_available': 11,
#   'legacy_id': '294',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 3,
#   'num_bikes_available': 24,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '8941eac9-fb07-4d76-b623-fae2af79139e',
#   'last_reported': 1754985982,
#   'num_ebikes_available': 8,
#   'legacy_id': '289',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 7,
#   'num_bikes_available': 15,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '6bcc6da3-b25b-4fea-9c30-3eb88e282574',
#   'last_reported': 1754985997,
#   'num_ebikes_available': 13,
#   'legacy_id': '283',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 1,
#   'num_bikes_available': 17,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '7ae6ad74-9212-4a2b-bb52-aba03cb533e2',
#   'last_reported': 1754986004,
#   'num_ebikes_available': 1,
#   'legacy_id': '279',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 1,
#   'num_bikes_available': 14,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '14f62ff9-1893-4379-8fe4-db578da909ee',
#   'last_reported': 1754986006,
#   'num_ebikes_available': 3,
#   'legacy_id': '494',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 1,
#   'num_bikes_available': 18,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '0fd9a51c-67ac-4048-b531-bff644b82f47',
#   'last_reported': 1754986006,
#   'num_ebikes_available': 12,
#   'legacy_id': '298',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 4,
#   'num_bikes_available': 19,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '3794a34d-764a-4af1-80db-1b0e0ce13fed',
#   'last_reported': 1754986003,
#   'num_ebikes_available': 0,
#   'legacy_id': '391',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 9,
#   'num_bikes_available': 10,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'daac8a55-dd65-4a1e-b0b9-65ec5002c812',
#   'last_reported': 1754986014,
#   'num_ebikes_available': 3,
#   'legacy_id': '307',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 9,
#   'num_bikes_available': 13,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'adda58ee-59a9-4586-8210-da874168a93b',
#   'last_reported': 1754986010,
#   'num_ebikes_available': 8,
#   'legacy_id': '301',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 3,
#   'num_bikes_available': 12,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '676591be-48bc-4653-995a-c4536e793135',
#   'last_reported': 1754986011,
#   'num_ebikes_available': 8,
#   'legacy_id': '297',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 10,
#   'num_bikes_available': 9,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '3c12fd1d-c7fc-4570-8fa3-1449c096b818',
#   'last_reported': 1754986011,
#   'num_ebikes_available': 0,
#   'legacy_id': '444',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 14,
#   'num_bikes_available': 4,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '891b961d-b674-49be-9579-71f5feb4598d',
#   'last_reported': 1754985931,
#   'num_ebikes_available': 3,
#   'legacy_id': '311',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 7,
#   'num_bikes_available': 12,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '5c17e1c8-5d21-4309-afcb-e69da27acf31',
#   'last_reported': 1754985935,
#   'num_ebikes_available': 1,
#   'legacy_id': '309',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 2,
#   'is_renting': 1,
#   'num_docks_available': 20,
#   'num_bikes_available': 1,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '14750571-71a2-4c2f-8a6a-8f344866eebe',
#   'last_reported': 1754985933,
#   'num_ebikes_available': 14,
#   'legacy_id': '427',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 0,
#   'num_bikes_available': 27,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '938f4dc0-e393-47e8-9449-3a82b2445662',
#   'last_reported': 1754985965,
#   'num_ebikes_available': 6,
#   'legacy_id': '401',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 5,
#   'num_bikes_available': 14,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '32974dc6-2aea-45d3-ae66-06f02f45ecaa',
#   'last_reported': 1754985984,
#   'num_ebikes_available': 3,
#   'legacy_id': '313',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 14,
#   'num_bikes_available': 9,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '28988488-fb74-4bbc-9e69-613698b2dd8c',
#   'last_reported': 1754985988,
#   'num_ebikes_available': 2,
#   'legacy_id': '35',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 5,
#   'num_bikes_available': 18,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '8fccc336-6544-4c73-a096-282131267f78',
#   'last_reported': 1754985992,
#   'num_ebikes_available': 10,
#   'legacy_id': '287',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 1,
#   'num_bikes_available': 17,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'dc464713-3263-40bd-a059-af2efd7a4b9a',
#   'last_reported': 1754986001,
#   'num_ebikes_available': 0,
#   'legacy_id': '286',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 14,
#   'num_bikes_available': 5,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '753e3e72-9498-4eef-a006-be1848cb36b3',
#   'last_reported': 1754985973,
#   'num_ebikes_available': 1,
#   'legacy_id': '295',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 11,
#   'num_bikes_available': 12,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'c0f36b61-82e5-4f63-9a28-1fa11f0149c9',
#   'last_reported': 1754985975,
#   'num_ebikes_available': 7,
#   'legacy_id': '402',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 4,
#   'num_bikes_available': 19,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '453a6d0d-31ce-4204-b2e1-2f9532e4b356',
#   'last_reported': 1754985978,
#   'num_ebikes_available': 1,
#   'legacy_id': '208',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 9,
#   'num_bikes_available': 10,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'ea511b7f-eae4-4ee8-9bba-ee7445e5133a',
#   'last_reported': 1754985980,
#   'num_ebikes_available': 2,
#   'legacy_id': '476',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 9,
#   'num_bikes_available': 6,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '7d8f4de7-d726-4af2-95b5-33032136239a',
#   'last_reported': 1754986019,
#   'num_ebikes_available': 4,
#   'legacy_id': '292',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 11,
#   'num_bikes_available': 8,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '93d95ded-d49e-43bc-b7fe-6ce556569088',
#   'last_reported': 1754985934,
#   'num_ebikes_available': 0,
#   'legacy_id': '93d95ded-d49e-43bc-b7fe-6ce556569088',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 14,
#   'num_bikes_available': 11,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'bb54f5c8-5578-4167-9599-8e55154de4fd',
#   'last_reported': 1754985932,
#   'num_ebikes_available': 4,
#   'legacy_id': '296',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 11,
#   'num_bikes_available': 16,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'd87d0852-6abb-428b-86dd-d470c64c8ff7',
#   'last_reported': 1754985942,
#   'num_ebikes_available': 7,
#   'legacy_id': '389',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 9,
#   'num_bikes_available': 14,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'ea2a009b-6a83-4b81-ba35-c175c492f4f4',
#   'last_reported': 1754985949,
#   'num_ebikes_available': 3,
#   'legacy_id': 'ea2a009b-6a83-4b81-ba35-c175c492f4f4',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 5,
#   'num_bikes_available': 13,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'cfda2dee-2f6c-400d-a1a7-ba1b2bdc6aee',
#   'last_reported': 1754985944,
#   'num_ebikes_available': 6,
#   'legacy_id': '392',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 2,
#   'num_bikes_available': 13,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '59a78eb1-a501-4145-b21f-bc2397898905',
#   'last_reported': 1754985954,
#   'num_ebikes_available': 2,
#   'legacy_id': '475',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 6,
#   'num_bikes_available': 9,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'b8cadddb-5ca8-43ec-98f3-2276e036950b',
#   'last_reported': 1754985955,
#   'num_ebikes_available': 0,
#   'legacy_id': '397',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 13,
#   'num_bikes_available': 9,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '7dfd8e07-81a8-4734-bc70-5e47aadbfa5a',
#   'last_reported': 1754985962,
#   'num_ebikes_available': 4,
#   'legacy_id': '281',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 2,
#   'is_renting': 1,
#   'num_docks_available': 8,
#   'num_bikes_available': 9,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'd6422284-e433-48c5-bf00-751c299189c8',
#   'last_reported': 1754985971,
#   'num_ebikes_available': 1,
#   'legacy_id': '304',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 16,
#   'num_bikes_available': 11,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '45d77294-6643-4ba4-bd8b-2e8c27430dfe',
#   'last_reported': 1754986001,
#   'num_ebikes_available': 5,
#   'legacy_id': '417',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 2,
#   'num_bikes_available': 21,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '27045384-791c-4519-8087-fce2f7c48a69',
#   'last_reported': 1754986002,
#   'num_ebikes_available': 5,
#   'legacy_id': '277',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 4,
#   'num_bikes_available': 15,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'caadcda3-bbdb-4cc5-825a-7e3d79ea921e',
#   'last_reported': 1754985983,
#   'num_ebikes_available': 2,
#   'legacy_id': '318',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 10,
#   'num_bikes_available': 5,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'cf792877-0b6a-4594-b388-8eb06599b549',
#   'last_reported': 1754986004,
#   'num_ebikes_available': 12,
#   'legacy_id': '473',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 0,
#   'num_bikes_available': 23,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '2c7560e6-62c6-4403-8b97-8016471948b5',
#   'last_reported': 1754985989,
#   'num_ebikes_available': 3,
#   'legacy_id': '276',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 3,
#   'num_bikes_available': 20,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'd68c980f-e659-4407-8e69-fea3ea84476a',
#   'last_reported': 1754986013,
#   'num_ebikes_available': 4,
#   'legacy_id': '491',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 11,
#   'num_bikes_available': 12,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '0cf3890c-4fde-49f7-9daa-7f2842695119',
#   'last_reported': 1754986015,
#   'num_ebikes_available': 5,
#   'legacy_id': '300',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 2,
#   'num_bikes_available': 17,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '13d36dad-f238-426c-9525-ec73552fa0b0',
#   'last_reported': 1754986015,
#   'num_ebikes_available': 4,
#   'legacy_id': '305',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 16,
#   'num_bikes_available': 6,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '534d8e3d-3814-48c9-b25e-1d2b8205fcd9',
#   'last_reported': 1754986016,
#   'num_ebikes_available': 8,
#   'legacy_id': '388',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 2,
#   'num_bikes_available': 13,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'b6d76c7a-2082-430b-8403-da5db00becaf',
#   'last_reported': 1754985912,
#   'num_ebikes_available': 1,
#   'legacy_id': '470',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 3,
#   'num_bikes_available': 20,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '2c00d99d-7518-4ecd-ab53-63e7a34034f6',
#   'last_reported': 1754985922,
#   'num_ebikes_available': 17,
#   'legacy_id': '406',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 0,
#   'num_bikes_available': 27,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '6c176d42-fea5-4df1-80eb-66a99cc73a21',
#   'last_reported': 1754985928,
#   'num_ebikes_available': 2,
#   'legacy_id': '290',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 0,
#   'num_bikes_available': 19,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '46f36a3a-f550-4fe0-bfe8-b94fddaf95d8',
#   'last_reported': 1754985988,
#   'num_ebikes_available': 5,
#   'legacy_id': '416',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 1,
#   'num_bikes_available': 21,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '6200707a-ffec-4dde-b142-4df69780264f',
#   'last_reported': 1754912221,
#   'num_ebikes_available': 0,
#   'legacy_id': '403',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 10,
#   'is_renting': 0,
#   'num_docks_available': 13,
#   'num_bikes_available': 0,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 0},
#  {'station_id': 'b09fd293-4364-4ce6-9341-0ced58486c5a',
#   'last_reported': 1754985987,
#   'num_ebikes_available': 11,
#   'legacy_id': '407',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 2,
#   'num_bikes_available': 13,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'e5b1f228-5347-47fc-a079-c1df0e8668f1',
#   'last_reported': 1754985954,
#   'num_ebikes_available': 9,
#   'legacy_id': '405',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 0,
#   'num_bikes_available': 27,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'bd217291-f4ad-4e1d-8c13-e27d39a35fef',
#   'last_reported': 1754985966,
#   'num_ebikes_available': 0,
#   'legacy_id': '327',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 14,
#   'num_bikes_available': 5,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'eb283c26-5d6b-4da4-a2ac-f0bfe3329856',
#   'last_reported': 1754985962,
#   'num_ebikes_available': 8,
#   'legacy_id': '472',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 1,
#   'num_bikes_available': 22,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'ccf416f8-ccc0-4f82-a659-e5d7851d2bcb',
#   'last_reported': 1754986006,
#   'num_ebikes_available': 7,
#   'legacy_id': '357',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 16,
#   'num_bikes_available': 7,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '94c877d2-f064-4373-b372-3f8997a07f30',
#   'last_reported': 1754986012,
#   'num_ebikes_available': 16,
#   'legacy_id': '423',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 5,
#   'num_bikes_available': 26,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '7c086aa7-c33f-47e5-ace9-74c40807c409',
#   'last_reported': 1754986014,
#   'num_ebikes_available': 7,
#   'legacy_id': '394',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 1,
#   'num_bikes_available': 22,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'c4c4484d-0e18-44d4-a992-c5d0550ba94d',
#   'last_reported': 1754985901,
#   'num_ebikes_available': 0,
#   'legacy_id': '358',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 15,
#   'num_bikes_available': 4,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '4298a24b-394a-491d-9d8f-df90f381b187',
#   'last_reported': 1754985903,
#   'num_ebikes_available': 8,
#   'legacy_id': '212',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 15,
#   'num_bikes_available': 16,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '63b2136c-c947-473e-977e-8cc0e6347699',
#   'last_reported': 1754985953,
#   'num_ebikes_available': 13,
#   'legacy_id': '492',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 4,
#   'num_bikes_available': 15,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '08f875e7-d696-4a4d-9656-43f07a953de4',
#   'last_reported': 1754985952,
#   'num_ebikes_available': 2,
#   'legacy_id': '257',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 2,
#   'num_bikes_available': 13,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'c3f56bed-65e3-425b-999e-82b3a4f73aeb',
#   'last_reported': 1754985952,
#   'num_ebikes_available': 4,
#   'legacy_id': '158',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 3,
#   'num_bikes_available': 15,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'cd4b4099-e2f5-4d46-bc1f-ed96d22548cc',
#   'last_reported': 1754985952,
#   'num_ebikes_available': 1,
#   'legacy_id': '173',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 3,
#   'num_bikes_available': 12,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'ef04d469-63f4-464a-946f-056da6318051',
#   'last_reported': 1754985950,
#   'num_ebikes_available': 3,
#   'legacy_id': '274',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 8,
#   'num_bikes_available': 12,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '2088720413948029938',
#   'last_reported': 1754985951,
#   'num_ebikes_available': 10,
#   'legacy_id': '2088720413948029938',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 3,
#   'num_bikes_available': 16,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'e66227f7-bd49-46be-b5ee-ce6518ac9dd4',
#   'last_reported': 1754985951,
#   'num_ebikes_available': 3,
#   'legacy_id': '345',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 16,
#   'num_bikes_available': 11,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '2039028142476895072',
#   'last_reported': 1754985909,
#   'num_ebikes_available': 4,
#   'legacy_id': '2039028142476895072',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 6,
#   'num_bikes_available': 13,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '924ea8a9-841d-43b5-99a9-bff7ca8d4b64',
#   'last_reported': 1754985909,
#   'num_ebikes_available': 0,
#   'legacy_id': '220',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 17,
#   'num_bikes_available': 2,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'b513d838-5423-490c-bf7d-9f20771cf529',
#   'last_reported': 1754985910,
#   'num_ebikes_available': 8,
#   'legacy_id': '456',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 5,
#   'num_bikes_available': 14,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '9a97cfb1-8882-4dfc-a075-2c22d646e457',
#   'last_reported': 1754985910,
#   'num_ebikes_available': 3,
#   'legacy_id': '116',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 20,
#   'num_bikes_available': 10,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '1bd76a29-5890-4194-993c-666c09af9993',
#   'last_reported': 1754985912,
#   'num_ebikes_available': 4,
#   'legacy_id': '387',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 9,
#   'num_bikes_available': 8,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '36ecea1d-48aa-416b-96d3-7698658759e5',
#   'last_reported': 1754985914,
#   'num_ebikes_available': 10,
#   'legacy_id': '571',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 8,
#   'num_bikes_available': 10,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'cf56994c-cdd6-4586-9f56-eea2f51e81ae',
#   'last_reported': 1754985918,
#   'num_ebikes_available': 0,
#   'legacy_id': '20',
#   'num_docks_disabled': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 30,
#   'num_bikes_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'cae028f4-b136-4297-8f28-559986e3f810',
#   'last_reported': 1754985914,
#   'num_ebikes_available': 1,
#   'legacy_id': '129',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 15,
#   'num_bikes_available': 4,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '2815280a-8263-4537-a944-4fdc32774fde',
#   'last_reported': 1754985920,
#   'num_ebikes_available': 11,
#   'legacy_id': '454',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 2,
#   'is_renting': 1,
#   'num_docks_available': 8,
#   'num_bikes_available': 13,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'b1a957d2-5e0e-4a99-bca3-7f3db21d30eb',
#   'last_reported': 1754985920,
#   'num_ebikes_available': 19,
#   'legacy_id': '71',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 1,
#   'num_bikes_available': 25,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '1903579136030360500',
#   'last_reported': 1754985916,
#   'num_ebikes_available': 5,
#   'legacy_id': '1903579136030360500',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 15,
#   'num_bikes_available': 11,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '2b935f1b-2659-4d82-a348-6a3bb083914d',
#   'last_reported': 1754985926,
#   'num_ebikes_available': 0,
#   'legacy_id': '21',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 32,
#   'num_bikes_available': 3,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '7b2083d3-b1bb-4ef3-ba53-bebc831bd0a4',
#   'last_reported': 1754985922,
#   'num_ebikes_available': 12,
#   'legacy_id': '371',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 3,
#   'num_bikes_available': 15,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'e4e5d6b1-a335-41a9-8efe-4c4d9294d6e2',
#   'last_reported': 1754985922,
#   'num_ebikes_available': 0,
#   'legacy_id': '90',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 19,
#   'num_bikes_available': 7,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '7018fb4d-6799-4a20-8ea4-739f789cd096',
#   'last_reported': 1754985923,
#   'num_ebikes_available': 0,
#   'legacy_id': '201',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 14,
#   'num_bikes_available': 9,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '1771130117010765886',
#   'last_reported': 1754985923,
#   'num_ebikes_available': 2,
#   'legacy_id': '1771130117010765886',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 8,
#   'num_bikes_available': 15,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'e4921f52-7a6c-4baa-b057-ddc7051980ca',
#   'last_reported': 1754985927,
#   'num_ebikes_available': 6,
#   'legacy_id': '232',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 8,
#   'num_bikes_available': 11,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '0d6a9101-5b40-4fdf-9315-e494af1baf7b',
#   'last_reported': 1754985927,
#   'num_ebikes_available': 0,
#   'legacy_id': '229',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 11,
#   'num_bikes_available': 7,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '9b4f6ef0-4568-4f52-8226-ec8432b75802',
#   'last_reported': 1754985924,
#   'num_ebikes_available': 1,
#   'legacy_id': '466',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 12,
#   'num_bikes_available': 9,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'd5eedd49-f998-4b8a-9d1a-22853da216aa',
#   'last_reported': 1754985924,
#   'num_ebikes_available': 5,
#   'legacy_id': '196',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 4,
#   'num_bikes_available': 18,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '2a229da1-a8bc-485a-982b-df0c9de6d11e',
#   'last_reported': 1754985931,
#   'num_ebikes_available': 0,
#   'legacy_id': '445',
#   'num_docks_disabled': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 19,
#   'num_bikes_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '492edeb7-7c9f-4845-b5cc-442faedb3a56',
#   'last_reported': 1754985929,
#   'num_ebikes_available': 2,
#   'legacy_id': '546',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 10,
#   'num_bikes_available': 9,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '9cac67a2-9219-455e-b3db-c771311c5b33',
#   'last_reported': 1754985930,
#   'num_ebikes_available': 2,
#   'legacy_id': '459',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 7,
#   'num_bikes_available': 7,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '47894de7-32c7-48ac-aa44-57c8def8a7f3',
#   'last_reported': 1754985928,
#   'num_ebikes_available': 0,
#   'legacy_id': '498',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 24,
#   'num_bikes_available': 3,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '1eef0966-a6b6-4da1-8726-09989c2eb044',
#   'last_reported': 1754985938,
#   'num_ebikes_available': 8,
#   'legacy_id': '152',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 9,
#   'num_bikes_available': 10,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '318b8d9d-cf10-41a5-988a-860a07f0543d',
#   'last_reported': 1754985933,
#   'num_ebikes_available': 0,
#   'legacy_id': '240',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 9,
#   'num_bikes_available': 10,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '7adb5dde-e34a-4964-98d3-f64a940beacb',
#   'last_reported': 1754985933,
#   'num_ebikes_available': 4,
#   'legacy_id': '245',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 22,
#   'num_bikes_available': 6,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '4938bd2c-37c1-4be9-9ad3-3b3d3d589248',
#   'last_reported': 1754985937,
#   'num_ebikes_available': 8,
#   'legacy_id': '524',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 7,
#   'num_bikes_available': 12,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '194a64ab-b6b4-4724-bd21-01b4e9cbe629',
#   'last_reported': 1754985942,
#   'num_ebikes_available': 4,
# ...
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '3a415706-d63c-4a35-9b1c-bb9127ddc925',
#   'last_reported': 1754985963,
#   'num_ebikes_available': 1,
#   'legacy_id': '499',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 20,
#   'num_bikes_available': 1,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '2106889672351971476',
#   'last_reported': 1754985966,
#   'num_ebikes_available': 1,
#   'legacy_id': '2106889672351971476',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 12,
#   'num_bikes_available': 6,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '18fb1a9a-e3ee-4a18-a00d-45c1e0d14d16',
#   'last_reported': 1754985967,
#   'num_ebikes_available': 11,
#   'legacy_id': '109',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 2,
#   'num_bikes_available': 17,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '8f34c934-e51e-4b0f-810c-916618b6cd90',
#   'last_reported': 1754985963,
#   'num_ebikes_available': 1,
#   'legacy_id': '202',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 18,
#   'num_bikes_available': 9,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '74e8630e-7e2a-447f-ae87-5c9898c7346a',
#   'last_reported': 1754985964,
#   'num_ebikes_available': 0,
#   'legacy_id': '180',
#   'num_docks_disabled': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 23,
#   'num_bikes_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '6b38a901-f4ae-4aef-b958-3b6efe69e9d6',
#   'last_reported': 1754985969,
#   'num_ebikes_available': 4,
#   'legacy_id': '385',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 2,
#   'num_bikes_available': 12,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '6b89ea9f-180b-4954-8eab-6cfeb2b66027',
#   'last_reported': 1754985962,
#   'num_ebikes_available': 1,
#   'legacy_id': '225',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 9,
#   'num_bikes_available': 6,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'f518d262-a592-4b3d-b026-b9215bea13d0',
#   'last_reported': 1754986005,
#   'num_ebikes_available': 18,
#   'legacy_id': '441',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 0,
#   'num_bikes_available': 22,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'e1242828-b89b-4d56-a78e-6a34fd7d3c00',
#   'last_reported': 1754986001,
#   'num_ebikes_available': 2,
#   'legacy_id': '453',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 14,
#   'num_bikes_available': 3,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '77948e35-f1c6-4ff9-9d8c-787a16b20a27',
#   'last_reported': 1754986002,
#   'num_ebikes_available': 1,
#   'legacy_id': '214',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 12,
#   'num_bikes_available': 6,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'd8b96e4a-7123-41db-a02c-e4ce48302578',
#   'last_reported': 1754986010,
#   'num_ebikes_available': 4,
#   'legacy_id': '76',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 11,
#   'num_bikes_available': 8,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'a9c46d92-b21e-489a-b922-3deb4ec1ab35',
#   'last_reported': 1754986008,
#   'num_ebikes_available': 3,
#   'legacy_id': '58',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 2,
#   'is_renting': 1,
#   'num_docks_available': 22,
#   'num_bikes_available': 5,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '586dce76-7324-4117-9c58-7ed6d00151bf',
#   'last_reported': 1754986012,
#   'num_ebikes_available': 0,
#   'legacy_id': '479',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 26,
#   'num_bikes_available': 1,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '2051240974562331110',
#   'last_reported': 1754986008,
#   'num_ebikes_available': 1,
#   'legacy_id': '2051240974562331110',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 9,
#   'num_bikes_available': 6,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '9ac7060b-f5d5-4ae4-be01-2571b1419d3f',
#   'last_reported': 1754986013,
#   'num_ebikes_available': 0,
#   'legacy_id': '228',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 15,
#   'num_bikes_available': 4,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'e5b0aca4-2ce6-49f8-82e8-8eed6e004147',
#   'last_reported': 1754986014,
#   'num_ebikes_available': 3,
#   'legacy_id': '10',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 26,
#   'num_bikes_available': 5,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'dcf29fa9-3304-4f6f-90eb-ef48ada9dbfe',
#   'last_reported': 1754986014,
#   'num_ebikes_available': 6,
#   'legacy_id': '174',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 9,
#   'num_bikes_available': 14,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '82ad4cff-001f-49a8-88fa-a5a63d64b9a2',
#   'last_reported': 1754986016,
#   'num_ebikes_available': 14,
#   'legacy_id': '82ad4cff-001f-49a8-88fa-a5a63d64b9a2',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 6,
#   'num_bikes_available': 15,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'cf1d4581-61da-4ade-97d5-2f856cdb0aad',
#   'last_reported': 1754986017,
#   'num_ebikes_available': 1,
#   'legacy_id': '237',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 9,
#   'num_bikes_available': 6,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '28925943-fddd-4f98-86ef-9f8dbd9bc62d',
#   'last_reported': 1754986018,
#   'num_ebikes_available': 0,
#   'legacy_id': '226',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 8,
#   'num_bikes_available': 7,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'f82dccaa-6309-4a54-a405-fe94412f71d6',
#   'last_reported': 1754986018,
#   'num_ebikes_available': 4,
#   'legacy_id': '251',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 4,
#   'num_bikes_available': 11,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'b6190b6b-1f42-4b69-ab79-d6cfa18adea7',
#   'last_reported': 1754986018,
#   'num_ebikes_available': 7,
#   'legacy_id': '137',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 10,
#   'num_bikes_available': 8,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'be15716e-f097-437b-8738-1db234d03b5e',
#   'last_reported': 1754986018,
#   'num_ebikes_available': 4,
#   'legacy_id': '477',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 1,
#   'is_renting': 1,
#   'num_docks_available': 14,
#   'num_bikes_available': 8,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': 'c6fc1429-ff65-428a-920c-f07aacdf51e8',
#   'last_reported': 1754986019,
#   'num_ebikes_available': 8,
#   'legacy_id': '523',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 14,
#   'num_bikes_available': 11,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '1875395906711399396',
#   'last_reported': 1698953637,
#   'num_ebikes_available': 0,
#   'legacy_id': '1875395906711399396',
#   'num_docks_disabled': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 4,
#   'num_bikes_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '1880193329986742730',
#   'last_reported': 1700096077,
#   'num_ebikes_available': 1,
#   'legacy_id': '1880193329986742730',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 0,
#   'num_bikes_available': 1,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '1881006687679115446',
#   'last_reported': 1754321880,
#   'num_ebikes_available': 0,
#   'legacy_id': '1881006687679115446',
#   'num_docks_disabled': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 20,
#   'num_bikes_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '1841972814951361200',
#   'last_reported': 1691418758,
#   'num_ebikes_available': 0,
#   'legacy_id': '1841972814951361200',
#   'num_docks_disabled': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 5,
#   'num_bikes_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '1880193329986742718',
#   'last_reported': 1700075155,
#   'num_ebikes_available': 0,
#   'legacy_id': '1880193329986742718',
#   'num_docks_disabled': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 4,
#   'num_bikes_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '1875048568201626296',
#   'last_reported': 1698950614,
#   'num_ebikes_available': 0,
#   'legacy_id': '1875048568201626296',
#   'num_docks_disabled': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 5,
#   'num_bikes_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '1880942617512231608',
#   'last_reported': 1700245080,
#   'num_ebikes_available': 0,
#   'legacy_id': '1880942617512231608',
#   'num_docks_disabled': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 16,
#   'num_bikes_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '1875048568201626286',
#   'last_reported': 1698950538,
#   'num_ebikes_available': 0,
#   'legacy_id': '1875048568201626286',
#   'num_docks_disabled': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 6,
#   'num_bikes_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '1875048572496593618',
#   'last_reported': 1698950716,
#   'num_ebikes_available': 0,
#   'legacy_id': '1875048572496593618',
#   'num_docks_disabled': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 10,
#   'num_bikes_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '1880193329986742724',
#   'last_reported': 1700070623,
#   'num_ebikes_available': 2,
#   'legacy_id': '1880193329986742724',
#   'num_docks_disabled': 0,
#   'num_scooters_unavailable': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 1,
#   'num_bikes_available': 2,
#   'num_scooters_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '1880193325691775420',
#   'last_reported': 1700070622,
#   'num_ebikes_available': 0,
#   'legacy_id': '1880193325691775420',
#   'num_docks_disabled': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 4,
#   'num_bikes_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '1880193329986742734',
#   'last_reported': 1700076043,
#   'num_ebikes_available': 0,
#   'legacy_id': '1880193329986742734',
#   'num_docks_disabled': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 5,
#   'num_bikes_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '1875048572496593608',
#   'last_reported': 1700076060,
#   'num_ebikes_available': 0,
#   'legacy_id': '1875048572496593608',
#   'num_docks_disabled': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 5,
#   'num_bikes_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '1841972814951361204',
#   'last_reported': 1691418718,
#   'num_ebikes_available': 0,
#   'legacy_id': '1841972814951361204',
#   'num_docks_disabled': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 5,
#   'num_bikes_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '1880942617512231614',
#   'last_reported': 1754321869,
#   'num_ebikes_available': 0,
#   'legacy_id': '1880942617512231614',
#   'num_docks_disabled': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 20,
#   'num_bikes_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '1841972814951361202',
#   'last_reported': 1691418745,
#   'num_ebikes_available': 0,
#   'legacy_id': '1841972814951361202',
#   'num_docks_disabled': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 8,
#   'num_bikes_available': 0,
#   'is_installed': 1,
#   'is_returning': 1},
#  {'station_id': '1841972814951361206',
#   'last_reported': 1691416974,
#   'num_ebikes_available': 0,
#   'legacy_id': '1841972814951361206',
#   'num_docks_disabled': 0,
#   'eightd_has_available_keys': False,
#   'num_bikes_disabled': 0,
#   'is_renting': 1,
#   'num_docks_available': 10,
#   'num_bikes_available': 0,
#   'is_installed': 1,
#   'is_returning': 1}]

# %%
region5_stations = []

for station in stations:
    if station["station_id"] in station_id_list:
        region5_stations.append(station)


print(len(region5_stations))


region5_stations[0]
# Out:
# 79
# {'station_id': '46b4ef45-b06b-40eb-9fdf-9bc8ff104a4f',
#  'last_reported': 1754985922,
#  'num_ebikes_available': 2,
#  'legacy_id': '299',
#  'num_docks_disabled': 0,
#  'num_scooters_unavailable': 0,
#  'eightd_has_available_keys': False,
#  'num_bikes_disabled': 0,
#  'is_renting': 1,
#  'num_docks_available': 7,
#  'num_bikes_available': 8,
#  'num_scooters_available': 0,
#  'is_installed': 1,
#  'is_returning': 1}

# %%
# create the df

df_live_feed = pd.DataFrame(region5_stations)
df_live_feed = df_live_feed.drop(["num_docks_disabled","eightd_has_available_keys","legacy_id"],axis=1)
df_live_feed.shape
# Out:
# (79, 11)

# %%
df_live_feed.head(10)
# Out:
#    num_bikes_available                            station_id  \
# 0                    8  46b4ef45-b06b-40eb-9fdf-9bc8ff104a4f
# 1                    7  ab8cc22e-0f34-4476-bf81-293cbbb2e69c
# 2                   12  68c89d1f-407a-4550-a2b7-ecf0ad7ee422
# 3                   11  0d48fc9e-6798-46f0-bbb6-67a168800e0b
# 4                    7  ed707a89-a68d-4921-a4cb-16c268e45a5b
# 5                   10  6994e1e6-bb3c-4309-8207-52e6004a7302
# 6                   14  dc2f7685-c3e3-4536-b78b-740479cbb207
# 7                   17  c53990d7-f965-40f4-b305-3435e1c95a71
# 8                    9  30429aed-9a47-4fd9-87fa-0db835aa8265
# 9                   15  7d59176c-49dd-4b07-a5ab-bcc109974db3
#
#    num_bikes_disabled  num_scooters_available  is_returning  last_reported  \
# 0                   0                       0             1     1754908120
# 1                   0                       0             1     1754908118
# 2                   2                       0             1     1754908123
# 3                   0                       0             1     1754908137
# 4                   1                       0             1     1754908192
# 5                   0                       0             1     1754908150
# 6                   3                       0             1     1754908173
# 7                   2                       0             1     1754908202
# 8                   0                       0             1     1754908203
# 9                   0                       0             1     1754908159
#
#    num_scooters_unavailable  is_renting  num_ebikes_available  \
# 0                         0           1                     2
# 1                         0           1                     1
# 2                         0           1                     7
# 3                         0           1                     4
# 4                         0           1                     5
# 5                         0           1                     2
# 6                         0           1                    14
# 7                         0           1                    16
# 8                         0           1                     3
# 9                         0           1                     6
#
#    num_docks_available  is_installed
# 0                    7             1
# 1                   20             1
# 2                    5             1
# 3                    4             1
# 4                   15             1
# 5                   13             1
# 6                   18             1
# 7                    0             1
# 8                    9             1
# 9                    4             1

# %% [markdown]
# ## Weather Data

# %%
from dotenv import load_dotenv
load_dotenv()
ninja_api = os.getenv("NINJAAPI")


# Latitude & Longitude values
lat=37.3382
lon=-121.8863


# API Ninjas endpoint with lat/lon
api_url = f'https://api.api-ninjas.com/v1/weather?lat={lat}&lon={lon}'

# Make the request
response = requests.get(api_url, headers={'X-Api-Key': ninja_api})

if response.status_code == requests.codes.ok:
    final_response = response.json()
    print(final_response)  # use .json() for parsed output
else:
    print("Error:", response.status_code, response.text)

def get_weather(lat,lon):
    api_url = f'https://api.api-ninjas.com/v1/weather?lat={lat}&lon={lon}'
    # Make the request
    response = requests.get(api_url, headers={'X-Api-Key': ninja_api})

    if response.status_code == requests.codes.ok:

        return response.json()

    else:
        return "error"


#need to add an extraction timestamp
# Out:
# {'cloud_pct': 100, 'temp': 17, 'feels_like': 17, 'humidity': 84, 'min_temp': 16, 'max_temp': 18, 'wind_speed': 1.54, 'wind_degrees': 360, 'sunrise': 1754918447, 'sunset': 1754967886}

# %%
weather_df = pd.DataFrame([final_response])
weather_df = weather_df.drop(['feels_like','wind_degrees'], axis= 1)

# %%
weather_df
# Out:
#    cloud_pct  temp  humidity  min_temp  max_temp  wind_speed     sunrise  \
# 0        100    17        84        16        18        1.54  1754918447
#
#        sunset
# 0  1754967886

# %% [markdown]
# ## Holiday Data

# %%
# Convert Unix timestamp (seconds) to local time + calendar features

import holidays

# Do it in the etl pipe

from datetime import datetime
import holidays

def date_converter(unix_ts: int):
    dt_local = datetime.fromtimestamp(unix_ts)  # no need for datetime.datetime
    is_weekday = dt_local.isoweekday()
    month = dt_local.month
    hour = dt_local.hour

    us_holidays = holidays.US()
    is_holiday = dt_local.date() in us_holidays

    return {
        "raw_time": unix_ts,
        "dt_local": dt_local,
        "is_weekday": is_weekday,
        "month": month,
        "hour": hour,
        "is_holiday": is_holiday
    }


d = date_converter(1754893182)
print(d)

df_datetime = pd.DataFrame([d])
df_datetime
# Out:
# {'raw_time': 1754893182, 'dt_local': datetime.datetime(2025, 8, 10, 23, 19, 42), 'is_weekday': 7, 'month': 8, 'hour': 23, 'is_holiday': False}
#      raw_time            dt_local  is_weekday  month  hour  is_holiday
# 0  1754893182 2025-08-10 23:19:42           7      8    23       False

# %% [markdown]
# ## Event Data

# %%
ticket_master_api = os.getenv('TICKETMASTER')

print(ticket_master_api)
# Out:
# EdEXhPQmgIagBHtdx19kFqcr3fC7oSe5

# %%
import os, time, requests
from datetime import datetime, timedelta, timezone

API_KEY = os.getenv("TICKETMASTER")
BASE_URL = "https://app.ticketmaster.com/discovery/v2/events.json"

def iso_utc(dt: datetime) -> str:
    if dt.tzinfo is None:
        dt = dt.replace(tzinfo=timezone.utc)
    return dt.astimezone(timezone.utc).strftime("%Y-%m-%dT%H:%M:%SZ")

def fetch_events_ticketmaster_miles(
    lat: float,
    lon: float,
    start_utc: datetime,
    end_utc: datetime,
    radius_miles: int = 1,     # send as INT, not float
    page_size: int = 100,      # smaller page while debugging
    max_pages: int = 10,
    sleep_sec: float = 0.2,
    apikey: str | None = None,
):
    apikey = apikey or API_KEY
    if not apikey:
        raise RuntimeError("Set TICKETMASTER_API_KEY env var or pass apikey=...")

    params = {
        "apikey": apikey,
        "latlong": f"{lat},{lon}",
        "radius": radius_miles,       # integer
        "unit": "miles",              # miles
        "startDateTime": iso_utc(start_utc),
        "endDateTime": iso_utc(end_utc),
        "countryCode": "US",
        "locale": "en-us",
        "size": page_size,
        "sort": "date,asc",
        "page": 0,
    }

    events = []
    for page in range(max_pages):
        params["page"] = page
        r = requests.get(BASE_URL, params=params, timeout=20)

        # retry on rate limit
        if r.status_code == 429:
            time.sleep(1.0)
            r = requests.get(BASE_URL, params=params, timeout=20)

        if not r.ok:
            # PRINT SERVER ERROR BODY to see exact reason
            try:
                print("Error body:", r.json())
            except Exception:
                print("Error body (text):", r.text)
            r.raise_for_status()

        data = r.json()
        page_events = (data.get("_embedded") or {}).get("events") or []
        if not page_events:
            break

        fetched_at = iso_utc(datetime.utcnow())
        for ev in page_events:
            classes = ev.get("classifications") or []
            seg = (classes[0].get("segment") or {}).get("name") if classes else None
            genr = (classes[0].get("genre") or {}).get("name") if classes else None

            venues = (ev.get("_embedded") or {}).get("venues") or []
            v = venues[0] if venues else {}
            loc = v.get("location") or {}
            try:
                lat_v = float(loc.get("latitude")) if loc.get("latitude") is not None else None
                lon_v = float(loc.get("longitude")) if loc.get("longitude") is not None else None
            except (TypeError, ValueError):
                lat_v = lon_v = None

            public_sales = (ev.get("sales") or {}).get("public") or {}

            events.append({
                #"event_id": ev.get("id"),
                #"name": ev.get("name"),
                "start_datetime": (ev.get("dates") or {}).get("start", {}).get("dateTime"),
                "timezone": (ev.get("dates") or {}).get("timezone"),
                #"venue_id": v.get("id"),
                #"venue_name": v.get("name"),
                #"venue_city": (v.get("city") or {}).get("name"),
                #"venue_state": (v.get("state") or {}).get("stateCode"),
                "venue_lat": lat_v,
                "venue_lon": lon_v,
                #"fetched_at": fetched_at,
                "source": "ticketmaster",
                "query_radius_miles": radius_miles,
                "query_lat": lat,
                "query_lon": lon,
            })

        page_info = data.get("page", {})
        if page >= page_info.get("totalPages", 1) - 1:
            break
        time.sleep(sleep_sec)

    count = {"events":events, "metadata":{"number_events": len(events), "radius_events": radius_miles} }

    return count

lat, lon = 37.323345, -121.913497
start = datetime.utcnow()
end = start + timedelta(days=2)

events = fetch_events_ticketmaster_miles(lat, lon, start, end, radius_miles=2)

print(f"Fetched {events} events")
# Out:
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/1922701392.py:109: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start = datetime.utcnow()
# Fetched {'events': [{'start_datetime': '2025-08-14T03:00:00Z', 'timezone': 'America/Los_Angeles', 'venue_lat': 37.335634, 'venue_lon': -121.887954, 'source': 'ticketmaster', 'query_radius_miles': 2, 'query_lat': 37.323345, 'query_lon': -121.913497}], 'metadata': {'number_events': 1, 'radius_events': 2}} events
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/1922701392.py:64: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   fetched_at = iso_utc(datetime.utcnow())

# %%
events
# Out:
# {'events': [{'start_datetime': '2025-08-14T03:00:00Z',
#    'timezone': 'America/Los_Angeles',
#    'venue_lat': 37.335634,
#    'venue_lon': -121.887954,
#    'source': 'ticketmaster',
#    'query_radius_miles': 2,
#    'query_lat': 37.323345,
#    'query_lon': -121.913497}],
#  'metadata': {'number_events': 1, 'radius_events': 2}}

# %%
events[0]
# Out:
# {'event_id': 'rZ7HnEZ1Af7kbd',
#  'name': 'Open Mic at the San Jose Improv',
#  'start_datetime': '2025-08-14T03:00:00Z',
#  'timezone': 'America/Los_Angeles',
#  'venue_id': 'rZ7HnEZ178E04',
#  'venue_name': 'San Jose Improv',
#  'venue_city': 'San Jose',
#  'venue_state': 'CA',
#  'venue_lat': 37.335634,
#  'venue_lon': -121.887954,
#  'fetched_at': '2025-08-11T10:32:16Z',
#  'source': 'ticketmaster',
#  'query_radius_miles': 2,
#  'query_lat': 37.323345,
#  'query_lon': -121.913497}

# %%
df.columns
# Out:
# Index(['station_id', 'rental_methods', 'name', 'capacity', 'lon', 'short_name',
#        'region_id', 'station_type', 'lat'],
#       dtype='object')

# %%
df_live_feed.columns
# Out:
# Index(['num_bikes_available', 'station_id', 'num_bikes_disabled',
#        'num_scooters_available', 'is_returning', 'last_reported',
#        'num_scooters_unavailable', 'is_renting', 'num_ebikes_available',
#        'num_docks_available', 'is_installed'],
#       dtype='object')

# %%
import pandas as pd

# Merge live feed with static station info
df_combined = pd.merge(
    df_live_feed,
    df,
    on="station_id",   # common key
    how="left"         # keep all live feed rows
)

df_combined
# Out:
#     num_bikes_available                            station_id  \
# 0                     8  46b4ef45-b06b-40eb-9fdf-9bc8ff104a4f
# 1                     7  ab8cc22e-0f34-4476-bf81-293cbbb2e69c
# 2                    12  68c89d1f-407a-4550-a2b7-ecf0ad7ee422
# 3                    11  0d48fc9e-6798-46f0-bbb6-67a168800e0b
# 4                     7  ed707a89-a68d-4921-a4cb-16c268e45a5b
# ..                  ...                                   ...
# 74                   25  94c877d2-f064-4373-b372-3f8997a07f30
# 75                   10  ccf416f8-ccc0-4f82-a659-e5d7851d2bcb
# 76                   22  eb283c26-5d6b-4da4-a2ac-f0bfe3329856
# 77                   10  6200707a-ffec-4dde-b142-4df69780264f
# 78                   19  b6d76c7a-2082-430b-8403-da5db00becaf
#
#     num_bikes_disabled  num_scooters_available  is_returning  last_reported  \
# 0                    0                       0             1     1754908120
# 1                    0                       0             1     1754908118
# 2                    2                       0             1     1754908123
# 3                    0                       0             1     1754908137
# 4                    1                       0             1     1754908192
# ..                 ...                     ...           ...            ...
# 74                   1                       0             1     1754908195
# 75                   1                       0             1     1754908208
# 76                   0                       0             1     1754908219
# 77                   0                       0             1     1754908224
# 78                   0                       0             1     1754908224
#
#     num_scooters_unavailable  is_renting  num_ebikes_available  \
# 0                          0           1                     2
# 1                          0           1                     1
# 2                          0           1                     7
# 3                          0           1                     4
# 4                          0           1                     5
# ..                       ...         ...                   ...
# 74                         0           1                    14
# 75                         0           1                    10
# 76                         0           1                     8
# 77                         0           1                     3
# 78                         0           1                     0
#
#     num_docks_available  is_installed     rental_methods  \
# 0                     7             1  [KEY, CREDITCARD]
# 1                    20             1  [KEY, CREDITCARD]
# 2                     5             1  [KEY, CREDITCARD]
# 3                     4             1  [KEY, CREDITCARD]
# 4                    15             1  [KEY, CREDITCARD]
# ..                  ...           ...                ...
# 74                    5             1  [KEY, CREDITCARD]
# 75                   12             1  [KEY, CREDITCARD]
# 76                    1             1  [KEY, CREDITCARD]
# 77                   13             1  [KEY, CREDITCARD]
# 78                    4             1  [KEY, CREDITCARD]
#
#                              name  capacity         lon short_name region_id  \
# 0                 Bestor Art Park        15 -121.874119     SJ-Q11         5
# 1        Kerley Dr at Rosemary St        27 -121.906834     SJ-F10         5
# 2   San Carlos St at Meridian Ave        19 -121.913497      SJ-M4         5
# 3             Julian St at 6th St        15 -121.888889     SJ-K11         5
# 4       San Fernando St at 7th St        23 -121.883215   SJ-M11-2         5
# ..                            ...       ...         ...        ...       ...
# 74           South San Jose State        31 -121.870099     SJ-R11         5
# 75            2nd St at Julian St        23 -121.892844     SJ-K10         5
# 76       Columbia Ave at Bird Ave        23 -121.899720      SJ-N7         5
# 77          10th St at Mission St        23 -121.892251     SJ-H12         5
# 78  N 14th St at E Santa Clara St        23 -121.877292     SJ-L12         5
#
#    station_type        lat
# 0       classic  37.323678
# 1       classic  37.360854
# 2       classic  37.323345
# 3       classic  37.342997
# 4       classic  37.337122
# ..          ...        ...
# 74      classic  37.320316
# 75      classic  37.341132
# 76      classic  37.324126
# 77      classic  37.355693
# 78      classic  37.342663
#
# [79 rows x 19 columns]

# %%
shape = df_combined.shape

for row in range(shape[0]):

        lat = df_combined.iloc[row]["lat"]
        lon = df_combined.iloc[row]["lon"]
        start = datetime.utcnow()
        end = start + timedelta(days=4)
        weather_data = get_weather(lat,lon)  # Json
        holiday_data = date_converter(df_combined.iloc[row]["last_reported"])
        event_data = fetch_events_ticketmaster_miles(lat, lon, start, end, radius_miles=2)

        final_json = weather_data|holiday_data|event_data
        temp_df = pd.DataFrame([final_json])







        print(temp_df)
# Out:
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/817692211.py:7: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start = datetime.utcnow()
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/2393209752.py:64: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   fetched_at = iso_utc(datetime.utcnow())
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/817692211.py:7: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start = datetime.utcnow()
#    cloud_pct  temp  feels_like  humidity  min_temp  max_temp  wind_speed  \
# 0        100    17          17        84        16        18        2.06
#
#    wind_degrees     sunrise      sunset    raw_time            dt_local  \
# 0           330  1754918445  1754967881  1754908120 2025-08-11 03:28:40
#
#    is_weekday  month  hour  is_holiday  number_events  radius_events
# 0           1      8     3       False              2              2
#    cloud_pct  temp  feels_like  humidity  min_temp  max_temp  wind_speed  \
# 0        100    17          17        85        16        18        2.06
#
#    wind_degrees     sunrise      sunset    raw_time            dt_local  \
# 0           330  1754918451  1754967894  1754908118 2025-08-11 03:28:38
#
#    is_weekday  month  hour  is_holiday  number_events  radius_events
# 0           1      8     3       False              0              2
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/817692211.py:7: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start = datetime.utcnow()
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/2393209752.py:64: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   fetched_at = iso_utc(datetime.utcnow())
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/817692211.py:7: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start = datetime.utcnow()
#    cloud_pct  temp  feels_like  humidity  min_temp  max_temp  wind_speed  \
# 0        100    17          17        85        15        18        2.06
#
#    wind_degrees     sunrise      sunset    raw_time            dt_local  \
# 0           330  1754918454  1754967890  1754908123 2025-08-11 03:28:43
#
#    is_weekday  month  hour  is_holiday  number_events  radius_events
# 0           1      8     3       False              2              2
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/2393209752.py:64: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   fetched_at = iso_utc(datetime.utcnow())
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/817692211.py:7: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start = datetime.utcnow()
#    cloud_pct  temp  feels_like  humidity  min_temp  max_temp  wind_speed  \
# 0        100    17          17        84        16        18        2.06
#
#    wind_degrees     sunrise      sunset    raw_time            dt_local  \
# 0           330  1754918446  1754967887  1754908137 2025-08-11 03:28:57
#
#    is_weekday  month  hour  is_holiday  number_events  radius_events
# 0           1      8     3       False              2              2
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/2393209752.py:64: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   fetched_at = iso_utc(datetime.utcnow())
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/817692211.py:7: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start = datetime.utcnow()
#    cloud_pct  temp  feels_like  humidity  min_temp  max_temp  wind_speed  \
# 0        100    17          17        84        16        18        2.06
#
#    wind_degrees     sunrise      sunset    raw_time            dt_local  \
# 0           330  1754918446  1754967885  1754908192 2025-08-11 03:29:52
#
#    is_weekday  month  hour  is_holiday  number_events  radius_events
# 0           1      8     3       False              2              2
#    cloud_pct  temp  feels_like  humidity  min_temp  max_temp  wind_speed  \
# 0        100    17          17        84        16        18        2.06
#
#    wind_degrees     sunrise      sunset    raw_time            dt_local  \
# 0           330  1754918439  1754967884  1754908150 2025-08-11 03:29:10
#
#    is_weekday  month  hour  is_holiday  number_events  radius_events
# 0           1      8     3       False              0              2
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/817692211.py:7: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start = datetime.utcnow()
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/2393209752.py:64: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   fetched_at = iso_utc(datetime.utcnow())
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/817692211.py:7: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start = datetime.utcnow()
#    cloud_pct  temp  feels_like  humidity  min_temp  max_temp  wind_speed  \
# 0        100    17          17        84        16        18        2.06
#
#    wind_degrees     sunrise      sunset    raw_time            dt_local  \
# 0           330  1754918451  1754967888  1754908173 2025-08-11 03:29:33
#
#    is_weekday  month  hour  is_holiday  number_events  radius_events
# 0           1      8     3       False              2              2
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/2393209752.py:64: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   fetched_at = iso_utc(datetime.utcnow())
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/817692211.py:7: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start = datetime.utcnow()
#    cloud_pct  temp  feels_like  humidity  min_temp  max_temp  wind_speed  \
# 0        100    17          17        84        16        18        2.06
#
#    wind_degrees     sunrise      sunset    raw_time            dt_local  \
# 0           330  1754918441  1754967882  1754908202 2025-08-11 03:30:02
#
#    is_weekday  month  hour  is_holiday  number_events  radius_events
# 0           1      8     3       False              2              2
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/2393209752.py:64: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   fetched_at = iso_utc(datetime.utcnow())
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/817692211.py:7: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start = datetime.utcnow()
#    cloud_pct  temp  feels_like  humidity  min_temp  max_temp  wind_speed  \
# 0        100    17          17        84        16        18        2.06
#
#    wind_degrees     sunrise      sunset    raw_time            dt_local  \
# 0           330  1754918443  1754967883  1754908203 2025-08-11 03:30:03
#
#    is_weekday  month  hour  is_holiday  number_events  radius_events
# 0           1      8     3       False              2              2
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/2393209752.py:64: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   fetched_at = iso_utc(datetime.utcnow())
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/817692211.py:7: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start = datetime.utcnow()
#    cloud_pct  temp  feels_like  humidity  min_temp  max_temp  wind_speed  \
# 0        100    17          17        84        16        18        2.06
#
#    wind_degrees     sunrise      sunset    raw_time            dt_local  \
# 0           330  1754918442  1754967886  1754908159 2025-08-11 03:29:19
#
#    is_weekday  month  hour  is_holiday  number_events  radius_events
# 0           1      8     3       False              2              2
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/2393209752.py:64: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   fetched_at = iso_utc(datetime.utcnow())
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/817692211.py:7: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start = datetime.utcnow()
#    cloud_pct  temp  feels_like  humidity  min_temp  max_temp  wind_speed  \
# 0        100    17          17        85        16        18        2.06
#
#    wind_degrees     sunrise      sunset    raw_time            dt_local  \
# 0           330  1754918449  1754967891  1754908180 2025-08-11 03:29:40
#
#    is_weekday  month  hour  is_holiday  number_events  radius_events
# 0           1      8     3       False              2              2
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/2393209752.py:64: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   fetched_at = iso_utc(datetime.utcnow())
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/817692211.py:7: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start = datetime.utcnow()
#    cloud_pct  temp  feels_like  humidity  min_temp  max_temp  wind_speed  \
# 0        100    17          17        84        16        18        2.06
#
#    wind_degrees     sunrise      sunset    raw_time            dt_local  \
# 0           330  1754918446  1754967887  1754908183 2025-08-11 03:29:43
#
#    is_weekday  month  hour  is_holiday  number_events  radius_events
# 0           1      8     3       False              2              2
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/2393209752.py:64: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   fetched_at = iso_utc(datetime.utcnow())
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/817692211.py:7: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start = datetime.utcnow()
#    cloud_pct  temp  feels_like  humidity  min_temp  max_temp  wind_speed  \
# 0        100    17          17        85        15        18        2.06
#
#    wind_degrees     sunrise      sunset    raw_time            dt_local  \
# 0           330  1754918452  1754967891  1754908219 2025-08-11 03:30:19
#
#    is_weekday  month  hour  is_holiday  number_events  radius_events
# 0           1      8     3       False              2              2
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/2393209752.py:64: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   fetched_at = iso_utc(datetime.utcnow())
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/817692211.py:7: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start = datetime.utcnow()
#    cloud_pct  temp  feels_like  humidity  min_temp  max_temp  wind_speed  \
# 0        100    17          17        84        16        18        2.06
#
#    wind_degrees     sunrise      sunset    raw_time            dt_local  \
# 0           330  1754918446  1754967887  1754908139 2025-08-11 03:28:59
#
#    is_weekday  month  hour  is_holiday  number_events  radius_events
# 0           1      8     3       False              2              2
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/2393209752.py:64: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   fetched_at = iso_utc(datetime.utcnow())
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/817692211.py:7: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start = datetime.utcnow()
#    cloud_pct  temp  feels_like  humidity  min_temp  max_temp  wind_speed  \
# 0        100    17          17        84        16        18        2.06
#
#    wind_degrees     sunrise      sunset    raw_time            dt_local  \
# 0           330  1754918451  1754967888  1754908141 2025-08-11 03:29:01
#
#    is_weekday  month  hour  is_holiday  number_events  radius_events
# 0           1      8     3       False              2              2
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/2393209752.py:64: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   fetched_at = iso_utc(datetime.utcnow())
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/817692211.py:7: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start = datetime.utcnow()
#    cloud_pct  temp  feels_like  humidity  min_temp  max_temp  wind_speed  \
# 0        100    17          17        84        16        18        2.06
#
#    wind_degrees     sunrise      sunset    raw_time            dt_local  \
# 0           330  1754918446  1754967887  1754908142 2025-08-11 03:29:02
#
#    is_weekday  month  hour  is_holiday  number_events  radius_events
# 0           1      8     3       False              2              2
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/2393209752.py:64: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   fetched_at = iso_utc(datetime.utcnow())
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/817692211.py:7: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start = datetime.utcnow()
#    cloud_pct  temp  feels_like  humidity  min_temp  max_temp  wind_speed  \
# 0        100    17          17        84        16        18        2.06
#
#    wind_degrees     sunrise      sunset    raw_time            dt_local  \
# 0           330  1754918446  1754967885  1754908166 2025-08-11 03:29:26
#
#    is_weekday  month  hour  is_holiday  number_events  radius_events
# 0           1      8     3       False              2              2
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/2393209752.py:64: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   fetched_at = iso_utc(datetime.utcnow())
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/817692211.py:7: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start = datetime.utcnow()
#    cloud_pct  temp  feels_like  humidity  min_temp  max_temp  wind_speed  \
# 0        100    17          17        85        16        18        2.06
#
#    wind_degrees     sunrise      sunset    raw_time            dt_local  \
# 0           330  1754918449  1754967891  1754908173 2025-08-11 03:29:33
#
#    is_weekday  month  hour  is_holiday  number_events  radius_events
# 0           1      8     3       False              2              2
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/2393209752.py:64: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   fetched_at = iso_utc(datetime.utcnow())
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/817692211.py:7: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start = datetime.utcnow()
#    cloud_pct  temp  feels_like  humidity  min_temp  max_temp  wind_speed  \
# 0        100    17          17        84        16        18        2.06
#
#    wind_degrees     sunrise      sunset    raw_time            dt_local  \
# 0           330  1754918447  1754967884  1754908181 2025-08-11 03:29:41
#
#    is_weekday  month  hour  is_holiday  number_events  radius_events
# 0           1      8     3       False              2              2
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/2393209752.py:64: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   fetched_at = iso_utc(datetime.utcnow())
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/817692211.py:7: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start = datetime.utcnow()
#    cloud_pct  temp  feels_like  humidity  min_temp  max_temp  wind_speed  \
# 0        100    17          17        84        16        18        2.06
#
#    wind_degrees     sunrise      sunset    raw_time            dt_local  \
# 0           330  1754918451  1754967888  1754908219 2025-08-11 03:30:19
#
#    is_weekday  month  hour  is_holiday  number_events  radius_events
# 0           1      8     3       False              2              2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 11
#       9 weather_data = get_weather(lat,lon)  # Json
#      10 holiday_data = date_converter(df_combined.iloc[row]["last_reported"])
# ---> 11 event_data = fetch_events_ticketmaster_miles(lat, lon, start, end, radius_miles=2)
#      13 final_json = weather_data|holiday_data|event_data
#      14 temp_df = pd.DataFrame([final_json])
#
# Cell In[33], line 44, in fetch_events_ticketmaster_miles(lat, lon, start_utc, end_utc, radius_miles, page_size, max_pages, sleep_sec, apikey)
#      42 for page in range(max_pages):
#      43     params["page"] = page
# ---> 44     r = requests.get(BASE_URL, params=params, timeout=20)
#      46     # retry on rate limit
#      47     if r.status_code == 429:
#
# File ~/Desktop/DockFlow/.venv/lib/python3.13/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Desktop/DockFlow/.venv/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Desktop/DockFlow/.venv/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Desktop/DockFlow/.venv/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Desktop/DockFlow/.venv/lib/python3.13/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/Desktop/DockFlow/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/Desktop/DockFlow/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/Desktop/DockFlow/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 # Force connect early to allow us to validate the connection.
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1096 if not conn.is_verified and not conn.proxy_is_verified:
#
# File ~/Desktop/DockFlow/.venv/lib/python3.13/site-packages/urllib3/connection.py:790, in HTTPSConnection.connect(self)
#     787     # Remove trailing '.' from fqdn hostnames to allow certificate validation
#     788     server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 790     sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     791         sock=sock,
#     792         cert_reqs=self.cert_reqs,
#     793         ssl_version=self.ssl_version,
#     794         ssl_minimum_version=self.ssl_minimum_version,
#     795         ssl_maximum_version=self.ssl_maximum_version,
#     796         ca_certs=self.ca_certs,
#     797         ca_cert_dir=self.ca_cert_dir,
#     798         ca_cert_data=self.ca_cert_data,
#     799         cert_file=self.cert_file,
#     800         key_file=self.key_file,
#     801         key_password=self.key_password,
#     802         server_hostname=server_hostname_rm_dot,
#     803         ssl_context=self.ssl_context,
#     804         tls_in_tls=tls_in_tls,
#     805         assert_hostname=self.assert_hostname,
#     806         assert_fingerprint=self.assert_fingerprint,
#     807     )
#     808     self.sock = sock_and_verified.socket
#     810 # If an error occurs during connection/handshake we may need to release
#     811 # our lock so another connection can probe the origin.
#
# File ~/Desktop/DockFlow/.venv/lib/python3.13/site-packages/urllib3/connection.py:969, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     966     if is_ipaddress(normalized):
#     967         server_hostname = normalized
# --> 969 ssl_sock = ssl_wrap_socket(
#     970     sock=sock,
#     971     keyfile=key_file,
#     972     certfile=cert_file,
#     973     key_password=key_password,
#     974     ca_certs=ca_certs,
#     975     ca_cert_dir=ca_cert_dir,
#     976     ca_cert_data=ca_cert_data,
#     977     server_hostname=server_hostname,
#     978     ssl_context=context,
#     979     tls_in_tls=tls_in_tls,
#     980 )
#     982 try:
#     983     if assert_fingerprint:
#
# File ~/Desktop/DockFlow/.venv/lib/python3.13/site-packages/urllib3/util/ssl_.py:480, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     476         context.load_cert_chain(certfile, keyfile, key_password)
#     478 context.set_alpn_protocols(ALPN_PROTOCOLS)
# --> 480 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     481 return ssl_sock
#
# File ~/Desktop/DockFlow/.venv/lib/python3.13/site-packages/urllib3/util/ssl_.py:524, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     521     SSLTransport._validate_ssl_context_for_tls_in_tls(ssl_context)
#     522     return SSLTransport(sock, ssl_context, server_hostname)
# --> 524 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1076, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1073             if timeout == 0.0:
#    1074                 # non-blocking
#    1075                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1076             self.do_handshake()
#    1077 except:
#    1078     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1372, in SSLSocket.do_handshake(self, block)
#    1370     if timeout == 0.0 and block:
#    1371         self.settimeout(None)
# -> 1372     self._sslobj.do_handshake()
#    1373 finally:
#    1374     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
shape = df_combined.shape

for row in range(shape[0]):
    lat = df_combined.iloc[row]["lat"]
    lon = df_combined.iloc[row]["lon"]

    start = datetime.utcnow()
    end = start + timedelta(days=4)

    weather_data = get_weather(lat, lon)                          # dict
    holiday_data = date_converter(df_combined.iloc[row]["last_reported"])  # dict
    event_data = fetch_events_ticketmaster_miles(lat, lon, start, end, radius_miles=2)  # dict

    final_json = weather_data | holiday_data | event_data          # single dict for this row

    # 1) Make sure all keys exist as columns
    for k in final_json.keys():
        if k not in df_combined.columns:
            df_combined[k] = pd.NA

    # 2) Write values into THIS ROW (in place)
    for k, v in final_json.items():
        df_combined.at[row, k] = v
# Out:
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/1533035867.py:7: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start = datetime.utcnow()
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/2393209752.py:64: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   fetched_at = iso_utc(datetime.utcnow())
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/1533035867.py:7: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start = datetime.utcnow()
# /var/folders/m8/x0f9131s0bnfbnqp15hmpbpw0000gn/T/ipykernel_30907/2393209752.py:64: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   fetched_at = iso_utc(datetime.utcnow())

# %%
df_combined.shape
# Out:
# (79, 37)

# %%
df_combined
# Out:
#     num_bikes_available                            station_id  \
# 0                     8  46b4ef45-b06b-40eb-9fdf-9bc8ff104a4f
# 1                     7  ab8cc22e-0f34-4476-bf81-293cbbb2e69c
# 2                    12  68c89d1f-407a-4550-a2b7-ecf0ad7ee422
# 3                    11  0d48fc9e-6798-46f0-bbb6-67a168800e0b
# 4                     7  ed707a89-a68d-4921-a4cb-16c268e45a5b
# ..                  ...                                   ...
# 74                   25  94c877d2-f064-4373-b372-3f8997a07f30
# 75                   10  ccf416f8-ccc0-4f82-a659-e5d7851d2bcb
# 76                   22  eb283c26-5d6b-4da4-a2ac-f0bfe3329856
# 77                   10  6200707a-ffec-4dde-b142-4df69780264f
# 78                   19  b6d76c7a-2082-430b-8403-da5db00becaf
#
#     num_bikes_disabled  num_scooters_available  is_returning  last_reported  \
# 0                    0                       0             1     1754908120
# 1                    0                       0             1     1754908118
# 2                    2                       0             1     1754908123
# 3                    0                       0             1     1754908137
# 4                    1                       0             1     1754908192
# ..                 ...                     ...           ...            ...
# 74                   1                       0             1     1754908195
# 75                   1                       0             1     1754908208
# 76                   0                       0             1     1754908219
# 77                   0                       0             1     1754908224
# 78                   0                       0             1     1754908224
#
#     num_scooters_unavailable  is_renting  num_ebikes_available  \
# 0                          0           1                     2
# 1                          0           1                     1
# 2                          0           1                     7
# 3                          0           1                     4
# 4                          0           1                     5
# ..                       ...         ...                   ...
# 74                         0           1                    14
# 75                         0           1                    10
# 76                         0           1                     8
# 77                         0           1                     3
# 78                         0           1                     0
#
#     num_docks_available  ...     sunrise      sunset    raw_time  \
# 0                     7  ...  1754918445  1754967881  1754908120
# 1                    20  ...  1754918449  1754967893  1754908118
# 2                     5  ...  1754918454  1754967890  1754908123
# 3                     4  ...  1754918447  1754967886  1754908137
# 4                    15  ...  1754918446  1754967885  1754908192
# ..                  ...  ...         ...         ...         ...
# 74                    5  ...  1754918445  1754967881  1754908195
# 75                   12  ...  1754918447  1754967886  1754908208
# 76                    1  ...  1754918452  1754967888  1754908219
# 77                   13  ...  1754918446  1754967889  1754908224
# 78                    4  ...  1754918446  1754967885  1754908224
#
#                dt_local  is_weekday month hour is_holiday  number_events  \
# 0   2025-08-11 03:28:40           1     8    3      False              2
# 1   2025-08-11 03:28:38           1     8    3      False              0
# 2   2025-08-11 03:28:43           1     8    3      False              2
# 3   2025-08-11 03:28:57           1     8    3      False              2
# 4   2025-08-11 03:29:52           1     8    3      False              2
# ..                  ...         ...   ...  ...        ...            ...
# 74  2025-08-11 03:29:55           1     8    3      False              2
# 75  2025-08-11 03:30:08           1     8    3      False              2
# 76  2025-08-11 03:30:19           1     8    3      False              2
# 77  2025-08-11 03:30:24           1     8    3      False              2
# 78  2025-08-11 03:30:24           1     8    3      False              2
#
#    radius_events
# 0              2
# 1              2
# 2              2
# 3              2
# 4              2
# ..           ...
# 74             2
# 75             2
# 76             2
# 77             2
# 78             2
#
# [79 rows x 37 columns]
